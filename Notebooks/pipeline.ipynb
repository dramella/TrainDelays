# %%
import pandas as pd
import numpy as np

# %%
new_df = pd.read_csv('EK_all.csv')
new_df
# Out:
# <ipython-input-10-8d594db68f00>:1: DtypeWarning: Columns (17,23,28,31,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv('EK_all.csv')
#        FINANCIAL_YEAR_AND_PERIOD ORIGIN_DEPARTURE_DATE  \
# 0                    2018/19_P01            2018-04-01
# 1                    2018/19_P01            2018-04-01
# 2                    2018/19_P01            2018-04-01
# 3                    2018/19_P01            2018-04-01
# 4                    2018/19_P01            2018-04-01
# ...                          ...                   ...
# 790290               2022/23_P11            2023-01-14
# 790291               2022/23_P11            2023-01-14
# 790292               2022/23_P12            2023-02-14
# 790293               2022/23_P12            2023-02-14
# 790294               2022/23_P12            2023-02-14
#
#        TRUST_TRAIN_ID_AFFECTED  PLANNED_ORIG_LOC_CODE_AFF  \
# 0                   502V19MF01                    50392.0
# 1                   502V36MO01                    50401.0
# 2                   502V59MY01                    50392.0
# 3                   502V35MN01                    50392.0
# 4                   502V49MU01                    50392.0
# ...                        ...                        ...
# 790290              879D60MZ14                    87651.0
# 790291              879D61MZ14                    87651.0
# 790292              872L39MP14                    87219.0
# 790293              872N40MP14                    87132.0
# 790294              879D35MO14                    87651.0
#
#        PLANNED_ORIG_GBTT_DATETIME_AFF PLANNED_ORIG_WTT_DATETIME_AFF  \
# 0                 2018-04-01 09:54:00           2018-04-01 09:54:00
# 1                 2018-04-01 14:11:00           2018-04-01 14:11:00
# 2                 2018-04-01 19:54:00           2018-04-01 19:54:00
# 3                 2018-04-01 13:54:00           2018-04-01 13:54:00
# 4                 2018-04-01 17:24:00           2018-04-01 17:24:00
# ...                               ...                           ...
# 790290            2023-01-14 20:16:00           2023-01-14 20:16:00
# 790291            2023-01-14 20:31:00           2023-01-14 20:31:00
# 790292            2023-02-14 14:46:00           2023-02-14 14:46:00
# 790293            2023-02-14 14:56:00           2023-02-14 14:56:00
# 790294            2023-02-14 14:01:00           2023-02-14 14:01:00
#
#         PLANNED_DEST_LOC_CODE_AFFECTED PLANNED_DEST_GBTT_DATETIME_AFF  \
# 0                              50401.0            2018-04-01 10:03:00
# 1                              50392.0            2018-04-01 14:20:00
# 2                              50401.0            2018-04-01 20:03:00
# 3                              50401.0            2018-04-01 14:03:00
# 4                              50401.0            2018-04-01 17:33:00
# ...                                ...                            ...
# 790290                         52051.0            2023-01-14 21:08:00
# 790291                         52051.0            2023-01-14 21:23:00
# 790292                         52226.0            2023-02-14 15:50:00
# 790293                         52226.0            2023-02-14 15:58:00
# 790294                         52051.0            2023-02-14 14:53:00
#
#        PLANNED_DEST_WTT_DATETIME_AFF  TRAIN_SERVICE_CODE_AFFECTED  ...  \
# 0                2018-04-01 10:03:00                     21237001  ...
# 1                2018-04-01 14:20:00                     21237001  ...
# 2                2018-04-01 20:03:00                     21237001  ...
# 3                2018-04-01 14:03:00                     21237001  ...
# 4                2018-04-01 17:33:00                     21237001  ...
# ...                              ...                          ...  ...
# 790290           2023-01-14 21:06:00                     22218000  ...
# 790291           2023-01-14 21:21:00                     22215003  ...
# 790292           2023-02-14 15:50:00                     22204000  ...
# 790293           2023-02-14 15:56:00                     22214000  ...
# 790294           2023-02-14 14:51:00                     22215003  ...
#
#        PFPI_MINUTES RESP_TRAIN REACT_TRAIN     Lat_OR    Lon_OR  \
# 0               0.0        NaN         NaN  51.559108  0.250912
# 1               0.0        NaN         NaN  51.574640  0.182370
# 2               0.0        NaN         NaN  51.559108  0.250912
# 3               0.0        NaN         NaN  51.559108  0.250912
# 4               0.0        NaN         NaN  51.559108  0.250912
# ...             ...        ...         ...        ...       ...
# 790290          0.0        NaN         NaN  51.475850 -0.040830
# 790291          5.0        NaN  872K611Z14  51.378426 -0.102560
# 790292          3.0        NaN  896V18CI14  51.471070 -0.169360
# 790293          3.0        NaN  872L39MP14  51.532500 -0.244540
# 790294          1.0        NaN  872K35MN14  51.378426 -0.102560
#
#                        STATION_OR    Lat_DES   Lon_DES  \
# 0          Upminster Rail Station  51.559108  0.250912
# 1                         ROMFORD  51.574640  0.182370
# 2          Upminster Rail Station  51.559108  0.250912
# 3          Upminster Rail Station  51.559108  0.250912
# 4          Upminster Rail Station  51.559108  0.250912
# ...                           ...        ...       ...
# 790290             NEW CROSS GATE  51.475850 -0.040830
# 790291  West Croydon Rail Station  51.397017 -0.075196
# 790292               LATCHMERE JN  51.497930 -0.210160
# 790293                        NaN  51.555480 -0.151360
# 790294  West Croydon Rail Station  51.397017 -0.075196
#
#                           STATION_DES  \
# 0              Upminster Rail Station
# 1                             ROMFORD
# 2              Upminster Rail Station
# 3              Upminster Rail Station
# 4              Upminster Rail Station
# ...                               ...
# 790290                 NEW CROSS GATE
# 790291  Norwood Junction Rail Station
# 790292           KENSINGTON (OLYMPIA)
# 790293                     GOSPEL OAK
# 790294  Norwood Junction Rail Station
#
#                               INCIDENT_REASON_DESCRIPTION
# 0       System generated cancellation (NOT to be attri...
# 1       System generated cancellation (NOT to be attri...
# 2       System generated cancellation (NOT to be attri...
# 3       System generated cancellation (NOT to be attri...
# 4       System generated cancellation (NOT to be attri...
# ...                                                   ...
# 790290  Delay due to incorrect ETCS system or equipmen...
# 790291  Delay due to incorrect ETCS system or equipmen...
# 790292  Confirmed shoe beam or associated system fault...
# 790293  Confirmed shoe beam or associated system fault...
# 790294  Confirmed shoe beam or associated system fault...
#
# [790295 rows x 46 columns]

# %%
import pandas as pd
import numpy as np

def cleaner(df):
    df.drop(columns=['TRAILING_LOAD_AFFECTED', 'TIMING_LOAD_AFFECTED', 'FINANCIAL_YEAR_AND_PERIOD',
                     'END_STANOX', 'START_STANOX','PLANNED_ORIG_LOC_CODE_AFF', 'INCIDENT_NUMBER','PLANNED_ORIG_GBTT_DATETIME_AFF','PLANNED_DEST_GBTT_DATETIME_AFF',
                     'PLANNED_DEST_LOC_CODE_AFFECTED', 'INCIDENT_START_DATETIME', 'INCIDENT_END_DATETIME',
                     'SECTION_CODE', 'ATTRIBUTION_STATUS', 'INCIDENT_EQUIPMENT', 'INCIDENT_DESCRIPTION',
                     'TRAIN_SCHEDULE_TYPE_AFFECTED', 'INCIDENT_RESPONSIBLE_TRAIN', 'EVENT_DATETIME', 'RESP_TRAIN',
                     'REACT_TRAIN', 'NETWORK_RAIL_LOCATION_MANAGER', 'OPERATOR_AFFECTED', 'ORIGIN_DEPARTURE_DATE',
                     'INCIDENT_REASON_DESCRIPTION', 'INCIDENT_CREATE_DATE'], inplace=True)

    df = df[df['TRAIN_SERVICE_CODE_AFFECTED'] != 22216001.0]

    return df

# %%
data = cleaner(new_df)
data
# Out:
#        TRUST_TRAIN_ID_AFFECTED PLANNED_ORIG_WTT_DATETIME_AFF  \
# 0                   502V19MF01           2018-04-01 09:54:00
# 1                   502V36MO01           2018-04-01 14:11:00
# 2                   502V59MY01           2018-04-01 19:54:00
# 3                   502V35MN01           2018-04-01 13:54:00
# 4                   502V49MU01           2018-04-01 17:24:00
# ...                        ...                           ...
# 790290              879D60MZ14           2023-01-14 20:16:00
# 790291              879D61MZ14           2023-01-14 20:31:00
# 790292              872L39MP14           2023-02-14 14:46:00
# 790293              872N40MP14           2023-02-14 14:56:00
# 790294              879D35MO14           2023-02-14 14:01:00
#
#        PLANNED_DEST_WTT_DATETIME_AFF  TRAIN_SERVICE_CODE_AFFECTED  \
# 0                2018-04-01 10:03:00                     21237001
# 1                2018-04-01 14:20:00                     21237001
# 2                2018-04-01 20:03:00                     21237001
# 3                2018-04-01 14:03:00                     21237001
# 4                2018-04-01 17:33:00                     21237001
# ...                              ...                          ...
# 790290           2023-01-14 21:06:00                     22218000
# 790291           2023-01-14 21:21:00                     22215003
# 790292           2023-02-14 15:50:00                     22204000
# 790293           2023-02-14 15:56:00                     22214000
# 790294           2023-02-14 14:51:00                     22215003
#
#        SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  \
# 0                             EK05               SU                      Y
# 1                             EK05               SU                      Y
# 2                             EK05               SU                      Y
# 3                             EK05               SU                      Y
# 4                             EK05               SU                      Y
# ...                            ...              ...                    ...
# 790290                        EK99               SA                      Y
# 790291                        EK03               SA                      Y
# 790292                        EK01               WD                      Y
# 790293                        EK01               WD                      Y
# 790294                        EK03               WD                      Y
#
#        TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED RESPONSIBLE_MANAGER  \
# 0                         EMU                317.0                PQHY
# 1                         EMU                317.0                PQHY
# 2                         EMU                317.0                PQHY
# 3                         EMU                317.0                PQHY
# 4                         EMU                317.0                PQHY
# ...                       ...                  ...                 ...
# 790290                    EMU                378.0                OQBN
# 790291                    EMU                378.0                OQBN
# 790292                    EMU                378.0                MHU3
# 790293                    EMU                378.0                MHU3
# 790294                    EMU                378.0                MHU3
#
#        INCIDENT_REASON REACTIONARY_REASON_CODE PERFORMANCE_EVENT_CODE  \
# 0                   PD                      PD                      S
# 1                   PD                      PD                      S
# 2                   PD                      PD                      S
# 3                   PD                      PD                      S
# 4                   PD                      PD                      S
# ...                ...                     ...                    ...
# 790290              OF                      TG                      P
# 790291              OF                      YD                      M
# 790292              MQ                      YB                      M
# 790293              MQ                      YD                      M
# 790294              MQ                      YD                      M
#
#         PFPI_MINUTES     Lat_OR    Lon_OR                 STATION_OR  \
# 0                0.0  51.559108  0.250912     Upminster Rail Station
# 1                0.0  51.574640  0.182370                    ROMFORD
# 2                0.0  51.559108  0.250912     Upminster Rail Station
# 3                0.0  51.559108  0.250912     Upminster Rail Station
# 4                0.0  51.559108  0.250912     Upminster Rail Station
# ...              ...        ...       ...                        ...
# 790290           0.0  51.475850 -0.040830             NEW CROSS GATE
# 790291           5.0  51.378426 -0.102560  West Croydon Rail Station
# 790292           3.0  51.471070 -0.169360               LATCHMERE JN
# 790293           3.0  51.532500 -0.244540                        NaN
# 790294           1.0  51.378426 -0.102560  West Croydon Rail Station
#
#           Lat_DES   Lon_DES                    STATION_DES
# 0       51.559108  0.250912         Upminster Rail Station
# 1       51.574640  0.182370                        ROMFORD
# 2       51.559108  0.250912         Upminster Rail Station
# 3       51.559108  0.250912         Upminster Rail Station
# 4       51.559108  0.250912         Upminster Rail Station
# ...           ...       ...                            ...
# 790290  51.475850 -0.040830                 NEW CROSS GATE
# 790291  51.397017 -0.075196  Norwood Junction Rail Station
# 790292  51.497930 -0.210160           KENSINGTON (OLYMPIA)
# 790293  51.555480 -0.151360                     GOSPEL OAK
# 790294  51.397017 -0.075196  Norwood Junction Rail Station
#
# [724095 rows x 20 columns]

# %%
X = df.drop(columns = 'PFPI_MINUTES')
y = new_df['PFPI_MINUTES']

# %%
data['PLANNED_ORIG_WTT_DATETIME_AFF'] = pd.to_datetime(data['PLANNED_ORIG_WTT_DATETIME_AFF'])
# Out:
# <ipython-input-20-b7349c2ad1d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PLANNED_ORIG_WTT_DATETIME_AFF'] = pd.to_datetime(data['PLANNED_ORIG_WTT_DATETIME_AFF'])

# %%
data['PLANNED_DEST_WTT_DATETIME_AFF'] = pd.to_datetime(data['PLANNED_DEST_WTT_DATETIME_AFF'])
# Out:
# <ipython-input-18-1765ff559289>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PLANNED_DEST_WTT_DATETIME_AFF'] = pd.to_datetime(data['PLANNED_DEST_WTT_DATETIME_AFF'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA

# %%
num_transformer = Pipeline(['minmax_scaler', MinMaxScaler()])

cat_transformer = OneHotEncoder(handle_unknown='ignore')

transformer = ColumnTransformer([('num_transformer', num_transformer),
                                 ('cat_transformer', num_transformer)],
                                 remainder = 'passthrough')


pipe = Pipeline([('transformer', transformer),('estimator', PCA())])

pipe
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_transformer',
#                                                   Pipeline(steps=['minmax_scaler',
#                                                                   MinMaxScaler()])),
#                                                  ('cat_transformer',
#                                                   Pipeline(steps=['minmax_scaler',
#                                                                   MinMaxScaler()]))])),
#                 ('estimator', PCA())])

# %%
# Out:
# dtype('O')
