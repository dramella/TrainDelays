# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pip install "flaml[automl]"
# Out:
# Collecting flaml[automl]
#   Downloading FLAML-2.1.1-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.23.5)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (4.1.0)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (2.0.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.11.4)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->flaml[automl]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->flaml[automl]) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->flaml[automl]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->flaml[automl]) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.4->flaml[automl]) (1.16.0)
# Installing collected packages: flaml
# Successfully installed flaml-2.1.1

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, learning_curve,ShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error,get_scorer_names
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold,cross_validate
from flaml import AutoML
import matplotlib.pyplot as plt
from flaml.automl.ml import sklearn_metric_loss_score
from flaml.automl.data import get_output_from_log
import pickle

# %%
rel_path = "/content/drive/MyDrive/clean_data_final.csv"
df = pd.read_csv(rel_path)

# %%
# Explore the Data
print("Head of the dataset:")
print(df.head())
# Out:
# Head of the dataset:
#    TRAIN_SERVICE_CODE_AFFECTED SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE  \
# 0                     22215003                        EK03               BH
# 1                     22215003                        EK03               BH
# 2                     22218000                        EK99               BH
# 3                     22218000                        EK99               BH
# 4                     22218000                        EK99               BH
#
#   APP_TIMETABLE_FLAG_AFF  UNIT_CLASS_AFFECTED INCIDENT_REASON  \
# 0                      Y                375.0               M
# 1                      Y                375.0               M
# 2                      Y                375.0               M
# 3                      Y                375.0               M
# 4                      Y                375.0               M
#
#   PERFORMANCE_EVENT_CODE  PFPI_MINUTES    Lat_OR   Lon_OR  ...  \
# 0                      M           9.0  51.54650 -0.10408  ...
# 1                      M           6.0  51.54650 -0.10408  ...
# 2                      M           0.0  51.54612 -0.07513  ...
# 3                      M           0.0  51.54612 -0.07513  ...
# 4                      M           0.0  51.54612 -0.07513  ...
#
#    ORIG_MINUTE_SIN  ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS  \
# 0        -0.309017         0.951057        0.406737        0.913545
# 1        -0.951057        -0.309017        0.406737        0.913545
# 2        -0.913545         0.406737        0.406737        0.913545
# 3        -0.994522        -0.104528        0.406737        0.913545
# 4        -0.809017         0.587785        0.406737        0.913545
#
#    DEST_DAY_SIN  DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# 0      0.207912      0.978148       0.669131      -0.743145    -9.781476e-01
# 1      0.207912      0.978148       0.978148      -0.207912    -2.079117e-01
# 2      0.207912      0.978148       0.978148      -0.207912     5.665539e-16
# 3      0.207912      0.978148       0.978148      -0.207912     5.000000e-01
# 4      0.207912      0.978148       0.978148      -0.207912    -4.067366e-01
#
#    DEST_MINUTE_COS
# 0         0.207912
# 1        -0.978148
# 2        -1.000000
# 3         0.866025
# 4        -0.913545
#
# [5 rows x 28 columns]

# %%
print("NANs:")
df.isnull().mean()
# Out:
# NANs:
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ENGLISH_DAY_TYPE               0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# UNIT_CLASS_AFFECTED            0.0
# INCIDENT_REASON                0.0
# PERFORMANCE_EVENT_CODE         0.0
# PFPI_MINUTES                   0.0
# Lat_OR                         0.0
# Lon_OR                         0.0
# Lat_DES                        0.0
# Lon_DES                        0.0
# ORIG_MONTH_SIN                 0.0
# ORIG_MONTH_COS                 0.0
# ORIG_DAY_SIN                   0.0
# ORIG_DAY_COS                   0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_HOUR_COS                  0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_MINUTE_COS                0.0
# DEST_MONTH_SIN                 0.0
# DEST_MONTH_COS                 0.0
# DEST_DAY_SIN                   0.0
# DEST_DAY_COS                   0.0
# DEST_HOUR_SIN                  0.0
# DEST_HOUR_COS                  0.0
# DEST_MINUTE_SIN                0.0
# DEST_MINUTE_COS                0.0
# dtype: float64

# %% [markdown]
# # Load Data and split train/test

# %%
# Split data into features and target
X = df.loc[:, df.columns != 'PFPI_MINUTES']
y = df['PFPI_MINUTES']

# Split data into train, test and validation sets: 70% train, 15% validation, 15% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (345275, 27) (147976, 27) (345275,) (147976,)

# %% [markdown]
# # Preprocessing

# %%
print("Before preprocessing - NAs - Train, Test")
display(X_train.isnull().mean().sort_values(ascending=False)*100)
display(X_test.isnull().mean().sort_values(ascending=False)*100)

print("Before preprocessing - Summary Statistics - Train, Test")
display(X_train.describe())
display(X_test.describe())
# Out:
# Before preprocessing - NAs - Train, Test
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# ORIG_DAY_COS                   0.0
# DEST_MINUTE_SIN                0.0
# DEST_HOUR_COS                  0.0
# DEST_HOUR_SIN                  0.0
# DEST_DAY_COS                   0.0
# DEST_DAY_SIN                   0.0
# DEST_MONTH_COS                 0.0
# DEST_MONTH_SIN                 0.0
# ORIG_MINUTE_COS                0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_HOUR_COS                  0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_DAY_SIN                   0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ORIG_MONTH_COS                 0.0
# ORIG_MONTH_SIN                 0.0
# Lon_DES                        0.0
# Lat_DES                        0.0
# Lon_OR                         0.0
# Lat_OR                         0.0
# PERFORMANCE_EVENT_CODE         0.0
# INCIDENT_REASON                0.0
# UNIT_CLASS_AFFECTED            0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# ENGLISH_DAY_TYPE               0.0
# DEST_MINUTE_COS                0.0
# dtype: float64
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# ORIG_DAY_COS                   0.0
# DEST_MINUTE_SIN                0.0
# DEST_HOUR_COS                  0.0
# DEST_HOUR_SIN                  0.0
# DEST_DAY_COS                   0.0
# DEST_DAY_SIN                   0.0
# DEST_MONTH_COS                 0.0
# DEST_MONTH_SIN                 0.0
# ORIG_MINUTE_COS                0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_HOUR_COS                  0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_DAY_SIN                   0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ORIG_MONTH_COS                 0.0
# ORIG_MONTH_SIN                 0.0
# Lon_DES                        0.0
# Lat_DES                        0.0
# Lon_OR                         0.0
# Lat_OR                         0.0
# PERFORMANCE_EVENT_CODE         0.0
# INCIDENT_REASON                0.0
# UNIT_CLASS_AFFECTED            0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# ENGLISH_DAY_TYPE               0.0
# DEST_MINUTE_COS                0.0
# dtype: float64
# Before preprocessing - Summary Statistics - Train, Test
#        TRAIN_SERVICE_CODE_AFFECTED  UNIT_CLASS_AFFECTED         Lat_OR  \
# count                 3.452750e+05        345275.000000  345275.000000
# mean                  2.213149e+07           449.817207      51.522185
# std                   6.439615e+05           148.155496       0.058136
# min                   2.123400e+07           313.000000      51.378426
# 25%                   2.192100e+07           375.000000      51.476840
# 50%                   2.221400e+07           378.000000      51.532500
# 75%                   2.221600e+07           378.000000      51.549263
# max                   2.523500e+07           710.000000      51.701930
#
#               Lon_OR        Lat_DES        Lon_DES  ORIG_MONTH_SIN  \
# count  345275.000000  345275.000000  345275.000000   345275.000000
# mean       -0.104402      51.524186      -0.102087        0.590277
# std         0.088767       0.053791       0.094511        0.275134
# min        -0.396494      51.378426      -0.396494        0.104528
# 25%        -0.151360      51.497990      -0.151360        0.309017
# 50%        -0.075070      51.532500      -0.071820        0.669131
# 75%        -0.059750      51.548450      -0.049710        0.866025
# max         0.329879      51.701930       0.329879        0.951057
#
#        ORIG_MONTH_COS   ORIG_DAY_SIN  ORIG_DAY_COS  ...  ORIG_MINUTE_SIN  \
# count   345275.000000  345275.000000  3.452750e+05  ...     3.452750e+05
# mean         0.724364       0.640435 -4.546323e-02  ...     1.403808e-02
# std          0.226210       0.320101  6.966443e-01  ...     7.022684e-01
# min          0.309017      -0.104528 -1.000000e+00  ...    -1.000000e+00
# 25%          0.500000       0.406737 -7.431448e-01  ...    -6.691306e-01
# 50%          0.743145       0.743145  2.832769e-16  ...     5.665539e-16
# 75%          0.951057       0.913545  5.877853e-01  ...     7.431448e-01
# max          0.994522       1.000000  9.945219e-01  ...     1.000000e+00
#
#        ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS   DEST_DAY_SIN  \
# count     3.452750e+05   345275.000000   345275.000000  345275.000000
# mean     -4.471968e-03        0.590273        0.724376       0.640496
# std       7.117619e-01        0.275127        0.226192       0.320109
# min      -1.000000e+00        0.104528        0.309017      -0.104528
# 25%      -7.431448e-01        0.309017        0.500000       0.406737
# 50%      -1.836970e-16        0.669131        0.743145       0.743145
# 75%       7.431448e-01        0.866025        0.951057       0.913545
# max       1.000000e+00        0.951057        0.994522       1.000000
#
#        DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# count  3.452750e+05  345275.000000   3.452750e+05     3.452750e+05
# mean  -4.550648e-02       0.829661   3.103203e-02     6.770891e-03
# std    6.965814e-01       0.196740   5.215309e-01     7.089889e-01
# min   -1.000000e+00       0.000000  -7.431448e-01    -1.000000e+00
# 25%   -7.431448e-01       0.743145  -4.067366e-01    -7.431448e-01
# 50%    2.832769e-16       0.866025   2.832769e-16     5.665539e-16
# 75%    5.877853e-01       0.951057   5.000000e-01     7.431448e-01
# max    9.945219e-01       1.000000   1.000000e+00     1.000000e+00
#
#        DEST_MINUTE_COS
# count     3.452750e+05
# mean     -6.293619e-04
# std       7.051889e-01
# min      -1.000000e+00
# 25%      -6.691306e-01
# 50%      -1.836970e-16
# 75%       6.691306e-01
# max       1.000000e+00
#
# [8 rows x 22 columns]
#        TRAIN_SERVICE_CODE_AFFECTED  UNIT_CLASS_AFFECTED         Lat_OR  \
# count                 1.479760e+05        147976.000000  147976.000000
# mean                  2.213006e+07           450.296406      51.522205
# std                   6.404362e+05           148.455498       0.058081
# min                   2.123400e+07           313.000000      51.378426
# 25%                   2.192100e+07           375.000000      51.476840
# 50%                   2.221400e+07           378.000000      51.532500
# 75%                   2.221600e+07           378.000000      51.549263
# max                   2.523500e+07           710.000000      51.701930
#
#               Lon_OR        Lat_DES        Lon_DES  ORIG_MONTH_SIN  \
# count  147976.000000  147976.000000  147976.000000   147976.000000
# mean       -0.104613      51.524212      -0.102175        0.589998
# std         0.088787       0.053850       0.094707        0.275831
# min        -0.396494      51.378426      -0.396494        0.104528
# 25%        -0.151360      51.497990      -0.151360        0.309017
# 50%        -0.075070      51.532500      -0.071820        0.669131
# 75%        -0.059750      51.548450      -0.049710        0.866025
# max         0.329879      51.701930       0.250912        0.951057
#
#        ORIG_MONTH_COS   ORIG_DAY_SIN  ORIG_DAY_COS  ...  ORIG_MINUTE_SIN  \
# count   147976.000000  147976.000000  1.479760e+05  ...     1.479760e+05
# mean         0.724158       0.640786 -4.510629e-02  ...     1.333998e-02
# std          0.226749       0.319573  6.965888e-01  ...     7.012119e-01
# min          0.309017      -0.104528 -1.000000e+00  ...    -1.000000e+00
# 25%          0.500000       0.406737 -7.431448e-01  ...    -6.691306e-01
# 50%          0.743145       0.743145  2.832769e-16  ...     5.665539e-16
# 75%          0.951057       0.913545  5.877853e-01  ...     7.431448e-01
# max          0.994522       1.000000  9.945219e-01  ...     1.000000e+00
#
#        ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS   DEST_DAY_SIN  \
# count     1.479760e+05   147976.000000   147976.000000  147976.000000
# mean     -4.656868e-03        0.590035        0.724156       0.640710
# std       7.128177e-01        0.275795        0.226704       0.319667
# min      -1.000000e+00        0.104528        0.309017      -0.104528
# 25%      -7.431448e-01        0.309017        0.500000       0.406737
# 50%      -1.836970e-16        0.669131        0.743145       0.743145
# 75%       7.431448e-01        0.866025        0.951057       0.913545
# max       1.000000e+00        0.951057        0.994522       1.000000
#
#        DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# count  1.479760e+05  147976.000000   1.479760e+05     1.479760e+05
# mean  -4.531776e-02       0.830980   3.017200e-02     6.404873e-03
# std    6.966020e-01       0.194495   5.203229e-01     7.079689e-01
# min   -1.000000e+00       0.000000  -7.431448e-01    -1.000000e+00
# 25%   -7.431448e-01       0.743145  -4.067366e-01    -7.431448e-01
# 50%    2.832769e-16       0.866025   2.832769e-16     5.665539e-16
# 75%    5.877853e-01       0.951057   5.000000e-01     7.431448e-01
# max    9.945219e-01       1.000000   1.000000e+00     1.000000e+00
#
#        DEST_MINUTE_COS
# count     1.479760e+05
# mean     -1.974581e-03
# std       7.062166e-01
# min      -1.000000e+00
# 25%      -6.691306e-01
# 50%      -1.836970e-16
# 75%       6.691306e-01
# max       1.000000e+00
#
# [8 rows x 22 columns]

# %%
# Build Pipeline
num_transformer = MinMaxScaler()
cat_transformer = OneHotEncoder(handle_unknown='ignore', sparse_output = False)
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

transformer = make_column_transformer((num_transformer, ['Lat_OR','Lon_OR', 'Lat_DES','Lon_DES']),
                                  (cat_transformer, ['ENGLISH_DAY_TYPE', 'SERVICE_GROUP_CODE_AFFECTED', 'INCIDENT_REASON',
                                                        'UNIT_CLASS_AFFECTED', 'TRAIN_SERVICE_CODE_AFFECTED',
                                                     'PERFORMANCE_EVENT_CODE',
                                                     'APP_TIMETABLE_FLAG_AFF']),
                                remainder = 'passthrough')
pipe = Pipeline([('transformer', transformer)])

# %%
pipe.fit(X_train)
X_train = pipe.transform(X_train)
X_test = pipe.transform(X_test)


X_train = pd.DataFrame(X_train, columns=pipe.get_feature_names_out())
X_test = pd.DataFrame(X_test, columns=pipe.get_feature_names_out())

# %%
print("After preprocessing - NAs - Train, Test")
display(X_train.isnull().mean().sort_values(ascending=False)*100)
display(X_test.isnull().mean().sort_values(ascending=False)*100)


print("After preprocessing - Summary Statistics - Train, Test")
display(X_train.describe())
display(X_test.describe())
# Out:
# After preprocessing - NAs - Train, Test
# minmaxscaler__Lat_OR                                   0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_22215002    0.0
# onehotencoder__PERFORMANCE_EVENT_CODE_A                0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25235001    0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25234001    0.0
#                                                       ...
# onehotencoder__UNIT_CLASS_AFFECTED_313.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_315.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_317.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_321.0               0.0
# remainder__DEST_MINUTE_COS                             0.0
# Length: 70, dtype: float64
# minmaxscaler__Lat_OR                                   0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_22215002    0.0
# onehotencoder__PERFORMANCE_EVENT_CODE_A                0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25235001    0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25234001    0.0
#                                                       ...
# onehotencoder__UNIT_CLASS_AFFECTED_313.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_315.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_317.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_321.0               0.0
# remainder__DEST_MINUTE_COS                             0.0
# Length: 70, dtype: float64
# After preprocessing - Summary Statistics - Train, Test
#        minmaxscaler__Lat_OR  minmaxscaler__Lon_OR  minmaxscaler__Lat_DES  \
# count         345275.000000         345275.000000          345275.000000
# mean               0.444380              0.402124               0.450567
# std                0.179706              0.122205               0.166276
# min                0.000000              0.000000               0.000000
# 25%                0.304213              0.337477               0.369591
# 50%                0.476266              0.442505               0.476266
# 75%                0.528084              0.463597               0.525570
# max                1.000000              1.000000               1.000000
#
#        minmaxscaler__Lon_DES  onehotencoder__ENGLISH_DAY_TYPE_BD  \
# count          345275.000000                       345275.000000
# mean                0.405310                            0.000041
# std                 0.130113                            0.006368
# min                 0.000000                            0.000000
# 25%                 0.337477                            0.000000
# 50%                 0.446980                            0.000000
# 75%                 0.477419                            0.000000
# max                 1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_BH  onehotencoder__ENGLISH_DAY_TYPE_SA  \
# count                       345275.000000                       345275.000000
# mean                             0.010557                            0.090858
# std                              0.102203                            0.287408
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_SU  onehotencoder__ENGLISH_DAY_TYPE_WD  \
# count                       345275.000000                       345275.000000
# mean                             0.072452                            0.826092
# std                              0.259236                            0.379031
# min                              0.000000                            0.000000
# 25%                              0.000000                            1.000000
# 50%                              0.000000                            1.000000
# 75%                              0.000000                            1.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__SERVICE_GROUP_CODE_AFFECTED_EK01  ...  \
# count                                    345275.000000  ...
# mean                                          0.392386  ...
# std                                           0.488283  ...
# min                                           0.000000  ...
# 25%                                           0.000000  ...
# 50%                                           0.000000  ...
# 75%                                           1.000000  ...
# max                                           1.000000  ...
#
#        remainder__ORIG_MINUTE_SIN  remainder__ORIG_MINUTE_COS  \
# count                3.452750e+05                3.452750e+05
# mean                 1.403808e-02               -4.471968e-03
# std                  7.022684e-01                7.117619e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -6.691306e-01               -7.431448e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                7.431448e-01
# max                  1.000000e+00                1.000000e+00
#
#        remainder__DEST_MONTH_SIN  remainder__DEST_MONTH_COS  \
# count              345275.000000              345275.000000
# mean                    0.590273                   0.724376
# std                     0.275127                   0.226192
# min                     0.104528                   0.309017
# 25%                     0.309017                   0.500000
# 50%                     0.669131                   0.743145
# 75%                     0.866025                   0.951057
# max                     0.951057                   0.994522
#
#        remainder__DEST_DAY_SIN  remainder__DEST_DAY_COS  \
# count            345275.000000             3.452750e+05
# mean                  0.640496            -4.550648e-02
# std                   0.320109             6.965814e-01
# min                  -0.104528            -1.000000e+00
# 25%                   0.406737            -7.431448e-01
# 50%                   0.743145             2.832769e-16
# 75%                   0.913545             5.877853e-01
# max                   1.000000             9.945219e-01
#
#        remainder__DEST_HOUR_SIN  remainder__DEST_HOUR_COS  \
# count             345275.000000              3.452750e+05
# mean                   0.829661              3.103203e-02
# std                    0.196740              5.215309e-01
# min                    0.000000             -7.431448e-01
# 25%                    0.743145             -4.067366e-01
# 50%                    0.866025              2.832769e-16
# 75%                    0.951057              5.000000e-01
# max                    1.000000              1.000000e+00
#
#        remainder__DEST_MINUTE_SIN  remainder__DEST_MINUTE_COS
# count                3.452750e+05                3.452750e+05
# mean                 6.770891e-03               -6.293619e-04
# std                  7.089889e-01                7.051889e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -7.431448e-01               -6.691306e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                6.691306e-01
# max                  1.000000e+00                1.000000e+00
#
# [8 rows x 70 columns]
#        minmaxscaler__Lat_OR  minmaxscaler__Lon_OR  minmaxscaler__Lat_DES  \
# count         147976.000000         147976.000000          147976.000000
# mean               0.444444              0.401833               0.450648
# std                0.179538              0.122233               0.166460
# min                0.000000              0.000000               0.000000
# 25%                0.304213              0.337477               0.369591
# 50%                0.476266              0.442505               0.476266
# 75%                0.528084              0.463597               0.525570
# max                1.000000              1.000000               1.000000
#
#        minmaxscaler__Lon_DES  onehotencoder__ENGLISH_DAY_TYPE_BD  \
# count          147976.000000                       147976.000000
# mean                0.405190                            0.000034
# std                 0.130384                            0.005813
# min                 0.000000                            0.000000
# 25%                 0.337477                            0.000000
# 50%                 0.446980                            0.000000
# 75%                 0.477419                            0.000000
# max                 0.891286                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_BH  onehotencoder__ENGLISH_DAY_TYPE_SA  \
# count                       147976.000000                       147976.000000
# mean                             0.010657                            0.090920
# std                              0.102682                            0.287496
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_SU  onehotencoder__ENGLISH_DAY_TYPE_WD  \
# count                       147976.000000                       147976.000000
# mean                             0.072938                            0.825451
# std                              0.260035                            0.379582
# min                              0.000000                            0.000000
# 25%                              0.000000                            1.000000
# 50%                              0.000000                            1.000000
# 75%                              0.000000                            1.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__SERVICE_GROUP_CODE_AFFECTED_EK01  ...  \
# count                                    147976.000000  ...
# mean                                          0.392476  ...
# std                                           0.488303  ...
# min                                           0.000000  ...
# 25%                                           0.000000  ...
# 50%                                           0.000000  ...
# 75%                                           1.000000  ...
# max                                           1.000000  ...
#
#        remainder__ORIG_MINUTE_SIN  remainder__ORIG_MINUTE_COS  \
# count                1.479760e+05                1.479760e+05
# mean                 1.333998e-02               -4.656868e-03
# std                  7.012119e-01                7.128177e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -6.691306e-01               -7.431448e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                7.431448e-01
# max                  1.000000e+00                1.000000e+00
#
#        remainder__DEST_MONTH_SIN  remainder__DEST_MONTH_COS  \
# count              147976.000000              147976.000000
# mean                    0.590035                   0.724156
# std                     0.275795                   0.226704
# min                     0.104528                   0.309017
# 25%                     0.309017                   0.500000
# 50%                     0.669131                   0.743145
# 75%                     0.866025                   0.951057
# max                     0.951057                   0.994522
#
#        remainder__DEST_DAY_SIN  remainder__DEST_DAY_COS  \
# count            147976.000000             1.479760e+05
# mean                  0.640710            -4.531776e-02
# std                   0.319667             6.966020e-01
# min                  -0.104528            -1.000000e+00
# 25%                   0.406737            -7.431448e-01
# 50%                   0.743145             2.832769e-16
# 75%                   0.913545             5.877853e-01
# max                   1.000000             9.945219e-01
#
#        remainder__DEST_HOUR_SIN  remainder__DEST_HOUR_COS  \
# count             147976.000000              1.479760e+05
# mean                   0.830980              3.017200e-02
# std                    0.194495              5.203229e-01
# min                    0.000000             -7.431448e-01
# 25%                    0.743145             -4.067366e-01
# 50%                    0.866025              2.832769e-16
# 75%                    0.951057              5.000000e-01
# max                    1.000000              1.000000e+00
#
#        remainder__DEST_MINUTE_SIN  remainder__DEST_MINUTE_COS
# count                1.479760e+05                1.479760e+05
# mean                 6.404873e-03               -1.974581e-03
# std                  7.079689e-01                7.062166e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -7.431448e-01               -6.691306e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                6.691306e-01
# max                  1.000000e+00                1.000000e+00
#
# [8 rows x 70 columns]

# %% [markdown]
# # Baseline Model

# %%
import numpy as np
# "Learn" the mean from the training data
mean_train = np.mean(y_train)
# Get predictions on the test set
baseline_predictions = np.ones(y_test.shape) * mean_train
# Compute MSE
mse_baseline = mean_squared_error(y_test, baseline_predictions)
print("Baseline MSE is {:.2f}".format(mse_baseline))
# Out:
# Baseline MSE is 28.08

# %% [markdown]
# # Regression Model with parameters optimized with AutoML

# %%
# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 600,  # in seconds
    "metric": 'mse',
    "task": 'regression',
    "log_file_name": "train_delays_regressor.log",
}
# Train with labeled input data
automl.fit(X_train=X_train, y_train=y_train,
           **automl_settings)
# Predict
print(automl.predict(X_train))
# Print the best model
print(automl.model.estimator)
# Out:
# [flaml.automl.logger: 12-05 15:56:46] {1679} INFO - task = regression
# [flaml.automl.logger: 12-05 15:56:46] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-05 15:56:47] {1788} INFO - Minimizing error metric: mse
# [flaml.automl.logger: 12-05 15:56:47] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 12-05 15:56:47] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:47] {2344} INFO - Estimated sufficient time budget=98138s. Estimated necessary time budget=692s.
# [flaml.automl.logger: 12-05 15:56:47] {2391} INFO -  at 9.3s,	estimator lgbm's best error=22.1544,	best estimator lgbm's best error=22.1544
# [flaml.automl.logger: 12-05 15:56:47] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:47] {2391} INFO -  at 9.6s,	estimator lgbm's best error=22.1544,	best estimator lgbm's best error=22.1544
# [flaml.automl.logger: 12-05 15:56:47] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:48] {2391} INFO -  at 10.1s,	estimator lgbm's best error=20.9682,	best estimator lgbm's best error=20.9682
# [flaml.automl.logger: 12-05 15:56:48] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:48] {2391} INFO -  at 10.6s,	estimator xgboost's best error=21.8936,	best estimator lgbm's best error=20.9682
# [flaml.automl.logger: 12-05 15:56:48] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:48] {2391} INFO -  at 10.8s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:48] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 10.9s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.1s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.3s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.3s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.5s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.5s,	estimator lgbm's best error=19.6306,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.6s,	estimator xgboost's best error=21.8936,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.7s,	estimator xgboost's best error=19.8263,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:49] {2391} INFO -  at 11.8s,	estimator xgboost's best error=19.8263,	best estimator lgbm's best error=19.6306
# [flaml.automl.logger: 12-05 15:56:49] {2218} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.0s,	estimator lgbm's best error=17.9595,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.1s,	estimator xgboost's best error=19.8263,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.2s,	estimator extra_tree's best error=21.7712,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.4s,	estimator lgbm's best error=17.9595,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.6s,	estimator extra_tree's best error=21.7712,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 12-05 15:56:50] {2391} INFO -  at 12.8s,	estimator extra_tree's best error=21.7712,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:50] {2218} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.0s,	estimator extra_tree's best error=21.1567,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.2s,	estimator lgbm's best error=17.9595,	best estimator lgbm's best error=17.9595
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.4s,	estimator lgbm's best error=17.7203,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.6s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.7s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:51] {2391} INFO -  at 13.8s,	estimator xgboost's best error=19.8263,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:51] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 12-05 15:56:52] {2391} INFO -  at 14.1s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:52] {2218} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 12-05 15:56:52] {2391} INFO -  at 14.5s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:52] {2218} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:52] {2391} INFO -  at 14.6s,	estimator xgboost's best error=19.5757,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:52] {2218} INFO - iteration 29, current learner rf
# [flaml.automl.logger: 12-05 15:56:53] {2391} INFO -  at 15.0s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.7203
# [flaml.automl.logger: 12-05 15:56:53] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:53] {2391} INFO -  at 15.2s,	estimator lgbm's best error=17.4434,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:53] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:53] {2391} INFO -  at 15.5s,	estimator lgbm's best error=17.4434,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:53] {2218} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:53] {2391} INFO -  at 15.7s,	estimator lgbm's best error=17.4434,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:53] {2218} INFO - iteration 33, current learner rf
# [flaml.automl.logger: 12-05 15:56:54] {2391} INFO -  at 16.3s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:54] {2218} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:54] {2391} INFO -  at 16.5s,	estimator lgbm's best error=17.4434,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:54] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 12-05 15:56:55] {2391} INFO -  at 17.0s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:55] {2218} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 12-05 15:56:55] {2391} INFO -  at 17.1s,	estimator xgboost's best error=19.5757,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:55] {2218} INFO - iteration 37, current learner rf
# [flaml.automl.logger: 12-05 15:56:58] {2391} INFO -  at 20.1s,	estimator rf's best error=19.5543,	best estimator lgbm's best error=17.4434
# [flaml.automl.logger: 12-05 15:56:58] {2218} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:58] {2391} INFO -  at 20.3s,	estimator lgbm's best error=17.2793,	best estimator lgbm's best error=17.2793
# [flaml.automl.logger: 12-05 15:56:58] {2218} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:58] {2391} INFO -  at 20.5s,	estimator lgbm's best error=17.2793,	best estimator lgbm's best error=17.2793
# [flaml.automl.logger: 12-05 15:56:58] {2218} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 12-05 15:56:58] {2391} INFO -  at 20.9s,	estimator lgbm's best error=17.2793,	best estimator lgbm's best error=17.2793
# [flaml.automl.logger: 12-05 15:56:58] {2218} INFO - iteration 41, current learner rf
# [flaml.automl.logger: 12-05 15:57:10] {2391} INFO -  at 32.1s,	estimator rf's best error=19.4610,	best estimator lgbm's best error=17.2793
# [flaml.automl.logger: 12-05 15:57:10] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:10] {2391} INFO -  at 32.4s,	estimator lgbm's best error=17.2691,	best estimator lgbm's best error=17.2691
# [flaml.automl.logger: 12-05 15:57:10] {2218} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:10] {2391} INFO -  at 32.6s,	estimator lgbm's best error=17.1511,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:10] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 12-05 15:57:11] {2391} INFO -  at 32.9s,	estimator extra_tree's best error=20.2255,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:11] {2218} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:11] {2391} INFO -  at 33.2s,	estimator lgbm's best error=17.1511,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:11] {2218} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:11] {2391} INFO -  at 33.4s,	estimator lgbm's best error=17.1511,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:11] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:11] {2391} INFO -  at 33.5s,	estimator xgboost's best error=19.5757,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:11] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:11] {2391} INFO -  at 33.8s,	estimator lgbm's best error=17.1511,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:11] {2218} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:12] {2391} INFO -  at 34.1s,	estimator lgbm's best error=17.1511,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:12] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 12-05 15:57:12] {2391} INFO -  at 34.5s,	estimator extra_tree's best error=20.2255,	best estimator lgbm's best error=17.1511
# [flaml.automl.logger: 12-05 15:57:12] {2218} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:13] {2391} INFO -  at 35.9s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:13] {2218} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:16] {2391} INFO -  at 38.7s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:16] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:20] {2391} INFO -  at 41.9s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:20] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:21] {2391} INFO -  at 43.4s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:21] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 12-05 15:57:21] {2391} INFO -  at 43.8s,	estimator extra_tree's best error=20.2255,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:21] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:23] {2391} INFO -  at 45.5s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:23] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:24] {2391} INFO -  at 46.7s,	estimator lgbm's best error=17.0111,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:24] {2218} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:24] {2391} INFO -  at 46.8s,	estimator xgboost's best error=19.5757,	best estimator lgbm's best error=17.0111
# [flaml.automl.logger: 12-05 15:57:24] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:26] {2391} INFO -  at 48.7s,	estimator lgbm's best error=16.9950,	best estimator lgbm's best error=16.9950
# [flaml.automl.logger: 12-05 15:57:26] {2218} INFO - iteration 60, current learner extra_tree
# [flaml.automl.logger: 12-05 15:57:27] {2391} INFO -  at 49.6s,	estimator extra_tree's best error=20.0733,	best estimator lgbm's best error=16.9950
# [flaml.automl.logger: 12-05 15:57:27] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:29] {2391} INFO -  at 51.4s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:29] {2218} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:33] {2391} INFO -  at 54.9s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:33] {2218} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:39] {2391} INFO -  at 61.0s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:39] {2218} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:40] {2391} INFO -  at 62.1s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:40] {2218} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:42] {2391} INFO -  at 64.6s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:42] {2218} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:42] {2391} INFO -  at 64.7s,	estimator xgboost's best error=19.5757,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:42] {2218} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:44] {2391} INFO -  at 66.0s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:44] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 12-05 15:57:51] {2391} INFO -  at 73.3s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:51] {2218} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:51] {2391} INFO -  at 73.8s,	estimator xgboost's best error=18.1645,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:51] {2218} INFO - iteration 70, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:52] {2391} INFO -  at 74.0s,	estimator xgboost's best error=18.0086,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:52] {2218} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:52] {2391} INFO -  at 74.3s,	estimator xgboost's best error=17.3952,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:52] {2218} INFO - iteration 72, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:52] {2391} INFO -  at 74.6s,	estimator xgboost's best error=17.3952,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:52] {2218} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:53] {2391} INFO -  at 75.0s,	estimator xgboost's best error=17.3952,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:53] {2218} INFO - iteration 74, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:53] {2391} INFO -  at 75.3s,	estimator xgboost's best error=17.3952,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:53] {2218} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:53] {2391} INFO -  at 75.6s,	estimator xgboost's best error=17.3952,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:53] {2218} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:55] {2391} INFO -  at 77.6s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:55] {2218} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 12-05 15:57:57] {2391} INFO -  at 79.4s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:57:57] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 12-05 15:58:00] {2391} INFO -  at 82.8s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:00] {2218} INFO - iteration 79, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:00] {2391} INFO -  at 82.9s,	estimator xgb_limitdepth's best error=20.5382,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:00] {2218} INFO - iteration 80, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.0s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.1s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 82, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.2s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 83, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.4s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 84, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.4s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 85, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:01] {2391} INFO -  at 83.6s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:01] {2218} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:02] {2391} INFO -  at 84.6s,	estimator xgb_limitdepth's best error=17.7961,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:02] {2218} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:03] {2391} INFO -  at 85.8s,	estimator xgb_limitdepth's best error=17.6547,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:03] {2218} INFO - iteration 88, current learner rf
# [flaml.automl.logger: 12-05 15:58:12] {2391} INFO -  at 94.4s,	estimator rf's best error=18.7890,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:12] {2218} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 12-05 15:58:13] {2391} INFO -  at 95.6s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:13] {2218} INFO - iteration 90, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:14] {2391} INFO -  at 95.9s,	estimator xgb_limitdepth's best error=17.6547,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:14] {2218} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 12-05 15:58:15] {2391} INFO -  at 97.8s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:15] {2218} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:16] {2391} INFO -  at 98.2s,	estimator xgb_limitdepth's best error=17.1107,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:16] {2218} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:16] {2391} INFO -  at 98.5s,	estimator xgb_limitdepth's best error=17.1107,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:16] {2218} INFO - iteration 94, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:16] {2391} INFO -  at 98.8s,	estimator xgb_limitdepth's best error=17.1107,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:16] {2218} INFO - iteration 95, current learner xgboost
# [flaml.automl.logger: 12-05 15:58:22] {2391} INFO -  at 104.8s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:22] {2218} INFO - iteration 96, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:58:23] {2391} INFO -  at 105.2s,	estimator xgb_limitdepth's best error=17.0731,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:23] {2218} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 12-05 15:58:25] {2391} INFO -  at 107.2s,	estimator xgboost's best error=17.1243,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:25] {2218} INFO - iteration 98, current learner extra_tree
# [flaml.automl.logger: 12-05 15:58:25] {2391} INFO -  at 107.5s,	estimator extra_tree's best error=20.0733,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:58:25] {2218} INFO - iteration 99, current learner rf
# [flaml.automl.logger: 12-05 15:59:11] {2391} INFO -  at 153.8s,	estimator rf's best error=18.7890,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:59:11] {2218} INFO - iteration 100, current learner lgbm
# [flaml.automl.logger: 12-05 15:59:13] {2391} INFO -  at 155.0s,	estimator lgbm's best error=16.7680,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:59:13] {2218} INFO - iteration 101, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:59:13] {2391} INFO -  at 155.3s,	estimator xgb_limitdepth's best error=17.0731,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:59:13] {2218} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 12-05 15:59:13] {2391} INFO -  at 155.8s,	estimator extra_tree's best error=20.0733,	best estimator lgbm's best error=16.7680
# [flaml.automl.logger: 12-05 15:59:13] {2218} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 12-05 15:59:17] {2391} INFO -  at 159.9s,	estimator lgbm's best error=16.5717,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 15:59:17] {2218} INFO - iteration 104, current learner extra_tree
# [flaml.automl.logger: 12-05 15:59:18] {2391} INFO -  at 160.9s,	estimator extra_tree's best error=18.8089,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 15:59:18] {2218} INFO - iteration 105, current learner extra_tree
# [flaml.automl.logger: 12-05 15:59:19] {2391} INFO -  at 161.4s,	estimator extra_tree's best error=18.8089,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 15:59:19] {2218} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 12-05 15:59:23] {2391} INFO -  at 165.1s,	estimator extra_tree's best error=18.8089,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 15:59:23] {2218} INFO - iteration 107, current learner xgb_limitdepth
# [flaml.automl.logger: 12-05 15:59:27] {2391} INFO -  at 168.9s,	estimator xgb_limitdepth's best error=17.0731,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 15:59:27] {2218} INFO - iteration 108, current learner rf
# [flaml.automl.logger: 12-05 16:06:38] {2391} INFO -  at 600.3s,	estimator rf's best error=17.3930,	best estimator lgbm's best error=16.5717
# [flaml.automl.logger: 12-05 16:06:43] {2627} INFO - retrain lgbm for 5.5s
# [flaml.automl.logger: 12-05 16:06:43] {2630} INFO - retrained model: LGBMRegressor(learning_rate=0.07936628267012258, max_bin=255,
#               min_child_samples=24, n_estimators=1, n_jobs=-1, num_leaves=16,
#               reg_alpha=0.49744183179244617, reg_lambda=0.1689067823740087,
#               verbose=-1)
# [flaml.automl.logger: 12-05 16:06:43] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-05 16:06:43] {1931} INFO - Time taken to find the best model: 159.87700724601746
# [1.36259035 1.73865673 1.53870296 ... 4.05018079 4.11616178 6.60187696]
# LGBMRegressor(learning_rate=0.07936628267012258, max_bin=255,
#               min_child_samples=24, n_estimators=1, n_jobs=-1, num_leaves=16,
#               reg_alpha=0.49744183179244617, reg_lambda=0.1689067823740087,
#               verbose=-1)

# %%
print('Best hyperparmeter config:', automl.best_config)
print('Best MSE on validation data: {0:.4g}'.format(1-automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
print(automl.model.estimator)
# Out:
# Best hyperparmeter config: {'n_estimators': 137, 'num_leaves': 16, 'min_child_samples': 24, 'learning_rate': 0.07936628267012258, 'log_max_bin': 8, 'colsample_bytree': 1.0, 'reg_alpha': 0.49744183179244617, 'reg_lambda': 0.1689067823740087}
# Best MSE on validation data: -15.57
# Training duration of best run: 5.522 s
# LGBMRegressor(learning_rate=0.07936628267012258, max_bin=255,
#               min_child_samples=24, n_estimators=1, n_jobs=-1, num_leaves=16,
#               reg_alpha=0.49744183179244617, reg_lambda=0.1689067823740087,
#               verbose=-1)

# %%
y_pred = automl.predict(X_test)
print('mse', '=', sklearn_metric_loss_score('mse', y_pred, y_test))
# Out:
# mse = 18.23226694550326

# %%
time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history =get_output_from_log(filename='train_delays_regressor.log', time_budget=60)
plt.title('Learning Curve')
plt.xlabel('Wall Clock Time (s)')
plt.ylabel('Validation MSE')
plt.step(time_history, 1 - np.array(best_valid_loss_history), where='post')
plt.show()

# %% [markdown]
# # Saving the model

# %%
automl.model.estimator
# Out:
# LGBMRegressor(learning_rate=0.07936628267012258, max_bin=255,
#               min_child_samples=24, n_estimators=1, n_jobs=-1, num_leaves=16,
#               reg_alpha=0.49744183179244617, reg_lambda=0.1689067823740087,
#               verbose=-1)

# %%
# Fit the model on training set
automl.model.estimator.fit(X_train, y_train)
# save the model to disk
filename = 'LGBMRegressor_MSE_on_test_18_23.sav'
pickle.dump(automl.model.estimator, open(filename, 'wb'))
