# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, learning_curve,ShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error,get_scorer_names
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold,cross_validate
from flaml import AutoML
import matplotlib.pyplot as plt
from flaml.automl.ml import sklearn_metric_loss_score
from flaml.automl.data import get_output_from_log

# %%
rel_path = "/content/drive/MyDrive/clean_data_final.csv"
df = pd.read_csv(rel_path)

# %%
# Explore the Data
print("Head of the dataset:")
print(df.head())
# Out:
# Head of the dataset:
#    TRAIN_SERVICE_CODE_AFFECTED SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE  \
# 0                     22215003                        EK03               BH
# 1                     22215003                        EK03               BH
# 2                     22218000                        EK99               BH
# 3                     22218000                        EK99               BH
# 4                     22218000                        EK99               BH
#
#   APP_TIMETABLE_FLAG_AFF  UNIT_CLASS_AFFECTED INCIDENT_REASON  \
# 0                      Y                375.0               M
# 1                      Y                375.0               M
# 2                      Y                375.0               M
# 3                      Y                375.0               M
# 4                      Y                375.0               M
#
#   PERFORMANCE_EVENT_CODE  PFPI_MINUTES    Lat_OR   Lon_OR  ...  \
# 0                      M           9.0  51.54650 -0.10408  ...
# 1                      M           6.0  51.54650 -0.10408  ...
# 2                      M           0.0  51.54612 -0.07513  ...
# 3                      M           0.0  51.54612 -0.07513  ...
# 4                      M           0.0  51.54612 -0.07513  ...
#
#    ORIG_MINUTE_SIN  ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS  \
# 0        -0.309017         0.951057        0.406737        0.913545
# 1        -0.951057        -0.309017        0.406737        0.913545
# 2        -0.913545         0.406737        0.406737        0.913545
# 3        -0.994522        -0.104528        0.406737        0.913545
# 4        -0.809017         0.587785        0.406737        0.913545
#
#    DEST_DAY_SIN  DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# 0      0.207912      0.978148       0.669131      -0.743145    -9.781476e-01
# 1      0.207912      0.978148       0.978148      -0.207912    -2.079117e-01
# 2      0.207912      0.978148       0.978148      -0.207912     5.665539e-16
# 3      0.207912      0.978148       0.978148      -0.207912     5.000000e-01
# 4      0.207912      0.978148       0.978148      -0.207912    -4.067366e-01
#
#    DEST_MINUTE_COS
# 0         0.207912
# 1        -0.978148
# 2        -1.000000
# 3         0.866025
# 4        -0.913545
#
# [5 rows x 28 columns]

# %%
print("NANs:")
df.isnull().mean()
# Out:
# NANs:
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ENGLISH_DAY_TYPE               0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# UNIT_CLASS_AFFECTED            0.0
# INCIDENT_REASON                0.0
# PERFORMANCE_EVENT_CODE         0.0
# PFPI_MINUTES                   0.0
# Lat_OR                         0.0
# Lon_OR                         0.0
# Lat_DES                        0.0
# Lon_DES                        0.0
# ORIG_MONTH_SIN                 0.0
# ORIG_MONTH_COS                 0.0
# ORIG_DAY_SIN                   0.0
# ORIG_DAY_COS                   0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_HOUR_COS                  0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_MINUTE_COS                0.0
# DEST_MONTH_SIN                 0.0
# DEST_MONTH_COS                 0.0
# DEST_DAY_SIN                   0.0
# DEST_DAY_COS                   0.0
# DEST_HOUR_SIN                  0.0
# DEST_HOUR_COS                  0.0
# DEST_MINUTE_SIN                0.0
# DEST_MINUTE_COS                0.0
# dtype: float64

# %% [markdown]
# # Load Data and split train/test

# %%
# Split data into features and target
X = df.loc[:, df.columns != 'PFPI_MINUTES']
y = df['PFPI_MINUTES']

# Split data into train, test and validation sets: 70% train, 15% validation, 15% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (345275, 27) (147976, 27) (345275,) (147976,)

# %% [markdown]
# # Preprocessing

# %%
print("Before preprocessing - NAs - Train, Test")
display(X_train.isnull().mean().sort_values(ascending=False)*100)
display(X_test.isnull().mean().sort_values(ascending=False)*100)

print("Before preprocessing - Summary Statistics - Train, Test")
display(X_train.describe())
display(X_test.describe())
# Out:
# Before preprocessing - NAs - Train, Test
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# ORIG_DAY_COS                   0.0
# DEST_MINUTE_SIN                0.0
# DEST_HOUR_COS                  0.0
# DEST_HOUR_SIN                  0.0
# DEST_DAY_COS                   0.0
# DEST_DAY_SIN                   0.0
# DEST_MONTH_COS                 0.0
# DEST_MONTH_SIN                 0.0
# ORIG_MINUTE_COS                0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_HOUR_COS                  0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_DAY_SIN                   0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ORIG_MONTH_COS                 0.0
# ORIG_MONTH_SIN                 0.0
# Lon_DES                        0.0
# Lat_DES                        0.0
# Lon_OR                         0.0
# Lat_OR                         0.0
# PERFORMANCE_EVENT_CODE         0.0
# INCIDENT_REASON                0.0
# UNIT_CLASS_AFFECTED            0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# ENGLISH_DAY_TYPE               0.0
# DEST_MINUTE_COS                0.0
# dtype: float64
# TRAIN_SERVICE_CODE_AFFECTED    0.0
# ORIG_DAY_COS                   0.0
# DEST_MINUTE_SIN                0.0
# DEST_HOUR_COS                  0.0
# DEST_HOUR_SIN                  0.0
# DEST_DAY_COS                   0.0
# DEST_DAY_SIN                   0.0
# DEST_MONTH_COS                 0.0
# DEST_MONTH_SIN                 0.0
# ORIG_MINUTE_COS                0.0
# ORIG_MINUTE_SIN                0.0
# ORIG_HOUR_COS                  0.0
# ORIG_HOUR_SIN                  0.0
# ORIG_DAY_SIN                   0.0
# SERVICE_GROUP_CODE_AFFECTED    0.0
# ORIG_MONTH_COS                 0.0
# ORIG_MONTH_SIN                 0.0
# Lon_DES                        0.0
# Lat_DES                        0.0
# Lon_OR                         0.0
# Lat_OR                         0.0
# PERFORMANCE_EVENT_CODE         0.0
# INCIDENT_REASON                0.0
# UNIT_CLASS_AFFECTED            0.0
# APP_TIMETABLE_FLAG_AFF         0.0
# ENGLISH_DAY_TYPE               0.0
# DEST_MINUTE_COS                0.0
# dtype: float64
# Before preprocessing - Summary Statistics - Train, Test
#        TRAIN_SERVICE_CODE_AFFECTED  UNIT_CLASS_AFFECTED         Lat_OR  \
# count                 3.452750e+05        345275.000000  345275.000000
# mean                  2.213149e+07           449.817207      51.522185
# std                   6.439615e+05           148.155496       0.058136
# min                   2.123400e+07           313.000000      51.378426
# 25%                   2.192100e+07           375.000000      51.476840
# 50%                   2.221400e+07           378.000000      51.532500
# 75%                   2.221600e+07           378.000000      51.549263
# max                   2.523500e+07           710.000000      51.701930
#
#               Lon_OR        Lat_DES        Lon_DES  ORIG_MONTH_SIN  \
# count  345275.000000  345275.000000  345275.000000   345275.000000
# mean       -0.104402      51.524186      -0.102087        0.590277
# std         0.088767       0.053791       0.094511        0.275134
# min        -0.396494      51.378426      -0.396494        0.104528
# 25%        -0.151360      51.497990      -0.151360        0.309017
# 50%        -0.075070      51.532500      -0.071820        0.669131
# 75%        -0.059750      51.548450      -0.049710        0.866025
# max         0.329879      51.701930       0.329879        0.951057
#
#        ORIG_MONTH_COS   ORIG_DAY_SIN  ORIG_DAY_COS  ...  ORIG_MINUTE_SIN  \
# count   345275.000000  345275.000000  3.452750e+05  ...     3.452750e+05
# mean         0.724364       0.640435 -4.546323e-02  ...     1.403808e-02
# std          0.226210       0.320101  6.966443e-01  ...     7.022684e-01
# min          0.309017      -0.104528 -1.000000e+00  ...    -1.000000e+00
# 25%          0.500000       0.406737 -7.431448e-01  ...    -6.691306e-01
# 50%          0.743145       0.743145  2.832769e-16  ...     5.665539e-16
# 75%          0.951057       0.913545  5.877853e-01  ...     7.431448e-01
# max          0.994522       1.000000  9.945219e-01  ...     1.000000e+00
#
#        ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS   DEST_DAY_SIN  \
# count     3.452750e+05   345275.000000   345275.000000  345275.000000
# mean     -4.471968e-03        0.590273        0.724376       0.640496
# std       7.117619e-01        0.275127        0.226192       0.320109
# min      -1.000000e+00        0.104528        0.309017      -0.104528
# 25%      -7.431448e-01        0.309017        0.500000       0.406737
# 50%      -1.836970e-16        0.669131        0.743145       0.743145
# 75%       7.431448e-01        0.866025        0.951057       0.913545
# max       1.000000e+00        0.951057        0.994522       1.000000
#
#        DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# count  3.452750e+05  345275.000000   3.452750e+05     3.452750e+05
# mean  -4.550648e-02       0.829661   3.103203e-02     6.770891e-03
# std    6.965814e-01       0.196740   5.215309e-01     7.089889e-01
# min   -1.000000e+00       0.000000  -7.431448e-01    -1.000000e+00
# 25%   -7.431448e-01       0.743145  -4.067366e-01    -7.431448e-01
# 50%    2.832769e-16       0.866025   2.832769e-16     5.665539e-16
# 75%    5.877853e-01       0.951057   5.000000e-01     7.431448e-01
# max    9.945219e-01       1.000000   1.000000e+00     1.000000e+00
#
#        DEST_MINUTE_COS
# count     3.452750e+05
# mean     -6.293619e-04
# std       7.051889e-01
# min      -1.000000e+00
# 25%      -6.691306e-01
# 50%      -1.836970e-16
# 75%       6.691306e-01
# max       1.000000e+00
#
# [8 rows x 22 columns]
#        TRAIN_SERVICE_CODE_AFFECTED  UNIT_CLASS_AFFECTED         Lat_OR  \
# count                 1.479760e+05        147976.000000  147976.000000
# mean                  2.213006e+07           450.296406      51.522205
# std                   6.404362e+05           148.455498       0.058081
# min                   2.123400e+07           313.000000      51.378426
# 25%                   2.192100e+07           375.000000      51.476840
# 50%                   2.221400e+07           378.000000      51.532500
# 75%                   2.221600e+07           378.000000      51.549263
# max                   2.523500e+07           710.000000      51.701930
#
#               Lon_OR        Lat_DES        Lon_DES  ORIG_MONTH_SIN  \
# count  147976.000000  147976.000000  147976.000000   147976.000000
# mean       -0.104613      51.524212      -0.102175        0.589998
# std         0.088787       0.053850       0.094707        0.275831
# min        -0.396494      51.378426      -0.396494        0.104528
# 25%        -0.151360      51.497990      -0.151360        0.309017
# 50%        -0.075070      51.532500      -0.071820        0.669131
# 75%        -0.059750      51.548450      -0.049710        0.866025
# max         0.329879      51.701930       0.250912        0.951057
#
#        ORIG_MONTH_COS   ORIG_DAY_SIN  ORIG_DAY_COS  ...  ORIG_MINUTE_SIN  \
# count   147976.000000  147976.000000  1.479760e+05  ...     1.479760e+05
# mean         0.724158       0.640786 -4.510629e-02  ...     1.333998e-02
# std          0.226749       0.319573  6.965888e-01  ...     7.012119e-01
# min          0.309017      -0.104528 -1.000000e+00  ...    -1.000000e+00
# 25%          0.500000       0.406737 -7.431448e-01  ...    -6.691306e-01
# 50%          0.743145       0.743145  2.832769e-16  ...     5.665539e-16
# 75%          0.951057       0.913545  5.877853e-01  ...     7.431448e-01
# max          0.994522       1.000000  9.945219e-01  ...     1.000000e+00
#
#        ORIG_MINUTE_COS  DEST_MONTH_SIN  DEST_MONTH_COS   DEST_DAY_SIN  \
# count     1.479760e+05   147976.000000   147976.000000  147976.000000
# mean     -4.656868e-03        0.590035        0.724156       0.640710
# std       7.128177e-01        0.275795        0.226704       0.319667
# min      -1.000000e+00        0.104528        0.309017      -0.104528
# 25%      -7.431448e-01        0.309017        0.500000       0.406737
# 50%      -1.836970e-16        0.669131        0.743145       0.743145
# 75%       7.431448e-01        0.866025        0.951057       0.913545
# max       1.000000e+00        0.951057        0.994522       1.000000
#
#        DEST_DAY_COS  DEST_HOUR_SIN  DEST_HOUR_COS  DEST_MINUTE_SIN  \
# count  1.479760e+05  147976.000000   1.479760e+05     1.479760e+05
# mean  -4.531776e-02       0.830980   3.017200e-02     6.404873e-03
# std    6.966020e-01       0.194495   5.203229e-01     7.079689e-01
# min   -1.000000e+00       0.000000  -7.431448e-01    -1.000000e+00
# 25%   -7.431448e-01       0.743145  -4.067366e-01    -7.431448e-01
# 50%    2.832769e-16       0.866025   2.832769e-16     5.665539e-16
# 75%    5.877853e-01       0.951057   5.000000e-01     7.431448e-01
# max    9.945219e-01       1.000000   1.000000e+00     1.000000e+00
#
#        DEST_MINUTE_COS
# count     1.479760e+05
# mean     -1.974581e-03
# std       7.062166e-01
# min      -1.000000e+00
# 25%      -6.691306e-01
# 50%      -1.836970e-16
# 75%       6.691306e-01
# max       1.000000e+00
#
# [8 rows x 22 columns]

# %%
# Build Pipeline
num_transformer = MinMaxScaler()
cat_transformer = OneHotEncoder(handle_unknown='ignore', sparse_output = False)
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

transformer = make_column_transformer((num_transformer, ['Lat_OR','Lon_OR', 'Lat_DES','Lon_DES']),
                                  (cat_transformer, ['ENGLISH_DAY_TYPE', 'SERVICE_GROUP_CODE_AFFECTED', 'INCIDENT_REASON',
                                                        'UNIT_CLASS_AFFECTED', 'TRAIN_SERVICE_CODE_AFFECTED',
                                                     'PERFORMANCE_EVENT_CODE',
                                                     'APP_TIMETABLE_FLAG_AFF']),
                                remainder = 'passthrough')
pipe = Pipeline([('transformer', transformer)])

# %%
pipe.fit(X_train)
X_train = pipe.transform(X_train)
X_test = pipe.transform(X_test)


X_train = pd.DataFrame(X_train, columns=pipe.get_feature_names_out())
X_test = pd.DataFrame(X_test, columns=pipe.get_feature_names_out())

# %%
print("After preprocessing - NAs - Train, Test")
display(X_train.isnull().mean().sort_values(ascending=False)*100)
display(X_test.isnull().mean().sort_values(ascending=False)*100)


print("After preprocessing - Summary Statistics - Train, Test")
display(X_train.describe())
display(X_test.describe())
# Out:
# After preprocessing - NAs - Train, Test
# minmaxscaler__Lat_OR                                   0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_22215002    0.0
# onehotencoder__PERFORMANCE_EVENT_CODE_A                0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25235001    0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25234001    0.0
#                                                       ...
# onehotencoder__UNIT_CLASS_AFFECTED_313.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_315.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_317.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_321.0               0.0
# remainder__DEST_MINUTE_COS                             0.0
# Length: 70, dtype: float64
# minmaxscaler__Lat_OR                                   0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_22215002    0.0
# onehotencoder__PERFORMANCE_EVENT_CODE_A                0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25235001    0.0
# onehotencoder__TRAIN_SERVICE_CODE_AFFECTED_25234001    0.0
#                                                       ...
# onehotencoder__UNIT_CLASS_AFFECTED_313.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_315.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_317.0               0.0
# onehotencoder__UNIT_CLASS_AFFECTED_321.0               0.0
# remainder__DEST_MINUTE_COS                             0.0
# Length: 70, dtype: float64
# After preprocessing - Summary Statistics - Train, Test
#        minmaxscaler__Lat_OR  minmaxscaler__Lon_OR  minmaxscaler__Lat_DES  \
# count         345275.000000         345275.000000          345275.000000
# mean               0.444380              0.402124               0.450567
# std                0.179706              0.122205               0.166276
# min                0.000000              0.000000               0.000000
# 25%                0.304213              0.337477               0.369591
# 50%                0.476266              0.442505               0.476266
# 75%                0.528084              0.463597               0.525570
# max                1.000000              1.000000               1.000000
#
#        minmaxscaler__Lon_DES  onehotencoder__ENGLISH_DAY_TYPE_BD  \
# count          345275.000000                       345275.000000
# mean                0.405310                            0.000041
# std                 0.130113                            0.006368
# min                 0.000000                            0.000000
# 25%                 0.337477                            0.000000
# 50%                 0.446980                            0.000000
# 75%                 0.477419                            0.000000
# max                 1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_BH  onehotencoder__ENGLISH_DAY_TYPE_SA  \
# count                       345275.000000                       345275.000000
# mean                             0.010557                            0.090858
# std                              0.102203                            0.287408
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_SU  onehotencoder__ENGLISH_DAY_TYPE_WD  \
# count                       345275.000000                       345275.000000
# mean                             0.072452                            0.826092
# std                              0.259236                            0.379031
# min                              0.000000                            0.000000
# 25%                              0.000000                            1.000000
# 50%                              0.000000                            1.000000
# 75%                              0.000000                            1.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__SERVICE_GROUP_CODE_AFFECTED_EK01  ...  \
# count                                    345275.000000  ...
# mean                                          0.392386  ...
# std                                           0.488283  ...
# min                                           0.000000  ...
# 25%                                           0.000000  ...
# 50%                                           0.000000  ...
# 75%                                           1.000000  ...
# max                                           1.000000  ...
#
#        remainder__ORIG_MINUTE_SIN  remainder__ORIG_MINUTE_COS  \
# count                3.452750e+05                3.452750e+05
# mean                 1.403808e-02               -4.471968e-03
# std                  7.022684e-01                7.117619e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -6.691306e-01               -7.431448e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                7.431448e-01
# max                  1.000000e+00                1.000000e+00
#
#        remainder__DEST_MONTH_SIN  remainder__DEST_MONTH_COS  \
# count              345275.000000              345275.000000
# mean                    0.590273                   0.724376
# std                     0.275127                   0.226192
# min                     0.104528                   0.309017
# 25%                     0.309017                   0.500000
# 50%                     0.669131                   0.743145
# 75%                     0.866025                   0.951057
# max                     0.951057                   0.994522
#
#        remainder__DEST_DAY_SIN  remainder__DEST_DAY_COS  \
# count            345275.000000             3.452750e+05
# mean                  0.640496            -4.550648e-02
# std                   0.320109             6.965814e-01
# min                  -0.104528            -1.000000e+00
# 25%                   0.406737            -7.431448e-01
# 50%                   0.743145             2.832769e-16
# 75%                   0.913545             5.877853e-01
# max                   1.000000             9.945219e-01
#
#        remainder__DEST_HOUR_SIN  remainder__DEST_HOUR_COS  \
# count             345275.000000              3.452750e+05
# mean                   0.829661              3.103203e-02
# std                    0.196740              5.215309e-01
# min                    0.000000             -7.431448e-01
# 25%                    0.743145             -4.067366e-01
# 50%                    0.866025              2.832769e-16
# 75%                    0.951057              5.000000e-01
# max                    1.000000              1.000000e+00
#
#        remainder__DEST_MINUTE_SIN  remainder__DEST_MINUTE_COS
# count                3.452750e+05                3.452750e+05
# mean                 6.770891e-03               -6.293619e-04
# std                  7.089889e-01                7.051889e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -7.431448e-01               -6.691306e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                6.691306e-01
# max                  1.000000e+00                1.000000e+00
#
# [8 rows x 70 columns]
#        minmaxscaler__Lat_OR  minmaxscaler__Lon_OR  minmaxscaler__Lat_DES  \
# count         147976.000000         147976.000000          147976.000000
# mean               0.444444              0.401833               0.450648
# std                0.179538              0.122233               0.166460
# min                0.000000              0.000000               0.000000
# 25%                0.304213              0.337477               0.369591
# 50%                0.476266              0.442505               0.476266
# 75%                0.528084              0.463597               0.525570
# max                1.000000              1.000000               1.000000
#
#        minmaxscaler__Lon_DES  onehotencoder__ENGLISH_DAY_TYPE_BD  \
# count          147976.000000                       147976.000000
# mean                0.405190                            0.000034
# std                 0.130384                            0.005813
# min                 0.000000                            0.000000
# 25%                 0.337477                            0.000000
# 50%                 0.446980                            0.000000
# 75%                 0.477419                            0.000000
# max                 0.891286                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_BH  onehotencoder__ENGLISH_DAY_TYPE_SA  \
# count                       147976.000000                       147976.000000
# mean                             0.010657                            0.090920
# std                              0.102682                            0.287496
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__ENGLISH_DAY_TYPE_SU  onehotencoder__ENGLISH_DAY_TYPE_WD  \
# count                       147976.000000                       147976.000000
# mean                             0.072938                            0.825451
# std                              0.260035                            0.379582
# min                              0.000000                            0.000000
# 25%                              0.000000                            1.000000
# 50%                              0.000000                            1.000000
# 75%                              0.000000                            1.000000
# max                              1.000000                            1.000000
#
#        onehotencoder__SERVICE_GROUP_CODE_AFFECTED_EK01  ...  \
# count                                    147976.000000  ...
# mean                                          0.392476  ...
# std                                           0.488303  ...
# min                                           0.000000  ...
# 25%                                           0.000000  ...
# 50%                                           0.000000  ...
# 75%                                           1.000000  ...
# max                                           1.000000  ...
#
#        remainder__ORIG_MINUTE_SIN  remainder__ORIG_MINUTE_COS  \
# count                1.479760e+05                1.479760e+05
# mean                 1.333998e-02               -4.656868e-03
# std                  7.012119e-01                7.128177e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -6.691306e-01               -7.431448e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                7.431448e-01
# max                  1.000000e+00                1.000000e+00
#
#        remainder__DEST_MONTH_SIN  remainder__DEST_MONTH_COS  \
# count              147976.000000              147976.000000
# mean                    0.590035                   0.724156
# std                     0.275795                   0.226704
# min                     0.104528                   0.309017
# 25%                     0.309017                   0.500000
# 50%                     0.669131                   0.743145
# 75%                     0.866025                   0.951057
# max                     0.951057                   0.994522
#
#        remainder__DEST_DAY_SIN  remainder__DEST_DAY_COS  \
# count            147976.000000             1.479760e+05
# mean                  0.640710            -4.531776e-02
# std                   0.319667             6.966020e-01
# min                  -0.104528            -1.000000e+00
# 25%                   0.406737            -7.431448e-01
# 50%                   0.743145             2.832769e-16
# 75%                   0.913545             5.877853e-01
# max                   1.000000             9.945219e-01
#
#        remainder__DEST_HOUR_SIN  remainder__DEST_HOUR_COS  \
# count             147976.000000              1.479760e+05
# mean                   0.830980              3.017200e-02
# std                    0.194495              5.203229e-01
# min                    0.000000             -7.431448e-01
# 25%                    0.743145             -4.067366e-01
# 50%                    0.866025              2.832769e-16
# 75%                    0.951057              5.000000e-01
# max                    1.000000              1.000000e+00
#
#        remainder__DEST_MINUTE_SIN  remainder__DEST_MINUTE_COS
# count                1.479760e+05                1.479760e+05
# mean                 6.404873e-03               -1.974581e-03
# std                  7.079689e-01                7.062166e-01
# min                 -1.000000e+00               -1.000000e+00
# 25%                 -7.431448e-01               -6.691306e-01
# 50%                  5.665539e-16               -1.836970e-16
# 75%                  7.431448e-01                6.691306e-01
# max                  1.000000e+00                1.000000e+00
#
# [8 rows x 70 columns]

# %% [markdown]
# # Baseline Model

# %%
import numpy as np
# "Learn" the mean from the training data
mean_train = np.mean(y_train)
# Get predictions on the test set
baseline_predictions = np.ones(y_test.shape) * mean_train
# Compute MSE
mse_baseline = mean_squared_error(y_test, baseline_predictions)
print("Baseline MSE is {:.2f}".format(mse_baseline))
# Out:
# Baseline MSE is 28.08

# %% [markdown]
# # Basic Model

# %%
# define basic model
basic_XGB = XGBRegressor(max_depth=10, n_estimators=100, learning_rate=0.1)
cv_results_basic_XGB = cross_validate(basic_XGB, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# %%
cv_results_basic_XGB['test_score']
# Out:
# array([-18.36922519, -20.57119743, -18.71321334, -19.4628965 ,
#        -16.03007883])

# %%
print("Basic Model MSE is {:.2f}".format(abs(cv_results_basic_XGB['test_score'].mean())))
# Out:
# Basic Model MSE is 18.63

# %% [markdown]
# # Model with Randomized Search

# %%
XGB_hyper_params = XGBRegressor()

# %%
# Parameters
parameters = {'booster':['gbtree'], # which booster to use: gbtree and dart use tree based models while gblinear uses linear functions.
             'nthread': [4], # number of parallel threads to use during training -> set equal to n° of CPU cores
              'learning_rate': [0.03, 0.05, 0.07], #hyperparameter that scales the contribution of each tree in the ensemble
              'max_depth': [3, 5, 7], # Maximum depth of a tree
              'min_child_weight': [1,2,4], #  controls the minimum sum of instance weight (hessian) needed in a child. It is used to control overfitting.
              }

# %%
# Set random search
random_search = RandomizedSearchCV(XGB_hyper_params, parameters, random_state=42, n_jobs=-1,cv=5, scoring='neg_mean_squared_error')
# Fit the model
random_search.fit(X_train, y_train)
# Print the best parameters
print("Best parameters: ", random_search.best_params_)
# Out:
# Best parameters:  {'nthread': 4, 'min_child_weight': 1, 'max_depth': 7, 'learning_rate': 0.07, 'booster': 'gbtree'}

# %%
print("Model with Randomized Search MSE is {:.2f}".format(abs(random_search.best_score_)))
# Out:
# Model with Randomized Search MSE is 18.44

# %% [markdown]
# # Model with parameters optimized with AutoML

# %%
automl = AutoML()
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'mse',  # primary metrics for regression can be chosen from: ['mae','mse','r2']
    "estimator_list": ['xgboost'],  # list of ML learners; we tune XGBoost in this example
    "task": 'regression',  # task type
    "log_file_name": 'train_delays_experiment.log',  # flaml log file
    "seed": 7654321,  # random seed
}
automl.fit(X_train=X_train, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 12-05 15:25:31] {1679} INFO - task = regression
# [flaml.automl.logger: 12-05 15:25:31] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-05 15:25:31] {1788} INFO - Minimizing error metric: mse
# [flaml.automl.logger: 12-05 15:25:31] {1900} INFO - List of ML learners in AutoML Run: ['xgboost']
# [flaml.automl.logger: 12-05 15:25:31] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:31] {2344} INFO - Estimated sufficient time budget=28589s. Estimated necessary time budget=29s.
# [flaml.automl.logger: 12-05 15:25:31] {2391} INFO -  at 9.5s,	estimator xgboost's best error=21.8936,	best estimator xgboost's best error=21.8936
# [flaml.automl.logger: 12-05 15:25:31] {2218} INFO - iteration 1, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:31] {2391} INFO -  at 9.6s,	estimator xgboost's best error=21.8936,	best estimator xgboost's best error=21.8936
# [flaml.automl.logger: 12-05 15:25:31] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 9.8s,	estimator xgboost's best error=19.4113,	best estimator xgboost's best error=19.4113
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 10.0s,	estimator xgboost's best error=19.4113,	best estimator xgboost's best error=19.4113
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 10.1s,	estimator xgboost's best error=19.4113,	best estimator xgboost's best error=19.4113
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 10.3s,	estimator xgboost's best error=19.4113,	best estimator xgboost's best error=19.4113
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 10.5s,	estimator xgboost's best error=19.0552,	best estimator xgboost's best error=19.0552
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:32] {2391} INFO -  at 10.6s,	estimator xgboost's best error=19.0552,	best estimator xgboost's best error=19.0552
# [flaml.automl.logger: 12-05 15:25:32] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:33] {2391} INFO -  at 11.0s,	estimator xgboost's best error=19.0552,	best estimator xgboost's best error=19.0552
# [flaml.automl.logger: 12-05 15:25:33] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:33] {2391} INFO -  at 11.2s,	estimator xgboost's best error=18.9743,	best estimator xgboost's best error=18.9743
# [flaml.automl.logger: 12-05 15:25:33] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:33] {2391} INFO -  at 11.5s,	estimator xgboost's best error=18.9743,	best estimator xgboost's best error=18.9743
# [flaml.automl.logger: 12-05 15:25:33] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:34] {2391} INFO -  at 11.7s,	estimator xgboost's best error=18.9743,	best estimator xgboost's best error=18.9743
# [flaml.automl.logger: 12-05 15:25:34] {2218} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:34] {2391} INFO -  at 11.9s,	estimator xgboost's best error=18.9743,	best estimator xgboost's best error=18.9743
# [flaml.automl.logger: 12-05 15:25:34] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:34] {2391} INFO -  at 12.1s,	estimator xgboost's best error=18.9743,	best estimator xgboost's best error=18.9743
# [flaml.automl.logger: 12-05 15:25:34] {2218} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:34] {2391} INFO -  at 12.6s,	estimator xgboost's best error=18.3119,	best estimator xgboost's best error=18.3119
# [flaml.automl.logger: 12-05 15:25:34] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:35] {2391} INFO -  at 13.2s,	estimator xgboost's best error=17.2869,	best estimator xgboost's best error=17.2869
# [flaml.automl.logger: 12-05 15:25:35] {2218} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:35] {2391} INFO -  at 13.7s,	estimator xgboost's best error=17.2869,	best estimator xgboost's best error=17.2869
# [flaml.automl.logger: 12-05 15:25:35] {2218} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:36] {2391} INFO -  at 14.2s,	estimator xgboost's best error=17.2869,	best estimator xgboost's best error=17.2869
# [flaml.automl.logger: 12-05 15:25:36] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:37] {2391} INFO -  at 14.8s,	estimator xgboost's best error=17.2869,	best estimator xgboost's best error=17.2869
# [flaml.automl.logger: 12-05 15:25:37] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:37] {2391} INFO -  at 15.6s,	estimator xgboost's best error=17.1180,	best estimator xgboost's best error=17.1180
# [flaml.automl.logger: 12-05 15:25:37] {2218} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:39] {2391} INFO -  at 16.7s,	estimator xgboost's best error=17.1180,	best estimator xgboost's best error=17.1180
# [flaml.automl.logger: 12-05 15:25:39] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:41] {2391} INFO -  at 19.5s,	estimator xgboost's best error=17.1180,	best estimator xgboost's best error=17.1180
# [flaml.automl.logger: 12-05 15:25:41] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:47] {2391} INFO -  at 25.4s,	estimator xgboost's best error=17.1180,	best estimator xgboost's best error=17.1180
# [flaml.automl.logger: 12-05 15:25:47] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 12-05 15:25:53] {2391} INFO -  at 30.8s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:25:53] {2218} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:01] {2391} INFO -  at 39.6s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:26:01] {2218} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:06] {2391} INFO -  at 44.3s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:26:06] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:17] {2391} INFO -  at 54.9s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:26:17] {2218} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:20] {2391} INFO -  at 58.7s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:26:20] {2218} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:33] {2391} INFO -  at 70.8s,	estimator xgboost's best error=16.4733,	best estimator xgboost's best error=16.4733
# [flaml.automl.logger: 12-05 15:26:33] {2218} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:39] {2391} INFO -  at 76.8s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:26:39] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:51] {2391} INFO -  at 89.4s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:26:51] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 12-05 15:26:57] {2391} INFO -  at 94.9s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:26:57] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 12-05 15:27:08] {2391} INFO -  at 106.0s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:27:08] {2218} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 12-05 15:27:14] {2391} INFO -  at 112.4s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:27:14] {2218} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 12-05 15:27:25] {2391} INFO -  at 123.1s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:27:25] {2218} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 12-05 15:27:28] {2391} INFO -  at 126.2s,	estimator xgboost's best error=16.0386,	best estimator xgboost's best error=16.0386
# [flaml.automl.logger: 12-05 15:27:28] {2218} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 12-05 15:27:52] {2391} INFO -  at 150.4s,	estimator xgboost's best error=15.7690,	best estimator xgboost's best error=15.7690
# [flaml.automl.logger: 12-05 15:27:52] {2218} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 12-05 15:28:04] {2391} INFO -  at 162.6s,	estimator xgboost's best error=15.7690,	best estimator xgboost's best error=15.7690
# [flaml.automl.logger: 12-05 15:28:04] {2218} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 12-05 15:28:41] {2391} INFO -  at 199.7s,	estimator xgboost's best error=15.7690,	best estimator xgboost's best error=15.7690
# [flaml.automl.logger: 12-05 15:28:42] {2218} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 12-05 15:29:03] {2391} INFO -  at 221.5s,	estimator xgboost's best error=15.7690,	best estimator xgboost's best error=15.7690
# [flaml.automl.logger: 12-05 15:29:03] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 12-05 15:29:20] {2391} INFO -  at 238.6s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:29:20] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 12-05 15:29:30] {2391} INFO -  at 248.0s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:29:30] {2218} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 12-05 15:30:02] {2391} INFO -  at 280.6s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:30:02] {2218} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 12-05 15:30:31] {2391} INFO -  at 309.0s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:30:31] {2218} INFO - iteration 44, current learner xgboost
# [flaml.automl.logger: 12-05 15:30:44] {2391} INFO -  at 322.0s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:30:44] {2218} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 12-05 15:30:59] {2391} INFO -  at 337.1s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:30:59] {2218} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 12-05 15:31:15] {2391} INFO -  at 352.9s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:31:15] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 12-05 15:31:39] {2391} INFO -  at 377.5s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:31:39] {2218} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 12-05 15:31:52] {2391} INFO -  at 389.9s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:31:52] {2218} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 12-05 15:32:17] {2391} INFO -  at 415.0s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:32:17] {2218} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 12-05 15:32:27] {2391} INFO -  at 424.8s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:32:27] {2218} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 12-05 15:32:34] {2391} INFO -  at 431.9s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:32:34] {2218} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 12-05 15:33:37] {2391} INFO -  at 495.1s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:33:37] {2218} INFO - iteration 53, current learner xgboost
# [flaml.automl.logger: 12-05 15:33:44] {2391} INFO -  at 502.3s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:33:44] {2218} INFO - iteration 54, current learner xgboost
# [flaml.automl.logger: 12-05 15:34:17] {2391} INFO -  at 535.4s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:34:17] {2218} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 12-05 15:34:27] {2391} INFO -  at 545.4s,	estimator xgboost's best error=15.6387,	best estimator xgboost's best error=15.6387
# [flaml.automl.logger: 12-05 15:34:27] {2218} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 12-05 15:34:59] {2391} INFO -  at 577.5s,	estimator xgboost's best error=15.6090,	best estimator xgboost's best error=15.6090
# [flaml.automl.logger: 12-05 15:35:32] {2627} INFO - retrain xgboost for 33.2s
# [flaml.automl.logger: 12-05 15:35:33] {2630} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.8161667576652838, colsample_bynode=None,
#              colsample_bytree=0.9952508738467774, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.017166482580903034,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=346,
#              min_child_weight=128.0, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=261, n_jobs=-1,
#              num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 12-05 15:35:33] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-05 15:35:33] {1931} INFO - Time taken to find the best model: 577.4890730381012

# %%
print('Best hyperparmeter config:', automl.best_config)
print('Best MSE on validation data: {0:.4g}'.format(1-automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
print(automl.model.estimator)
# Out:
# Best hyperparmeter config: {'n_estimators': 261, 'max_leaves': 346, 'min_child_weight': 128.0, 'learning_rate': 0.017166482580903034, 'subsample': 0.7150439793049789, 'colsample_bylevel': 0.8161667576652838, 'colsample_bytree': 0.9952508738467774, 'reg_alpha': 0.3769842888621665, 'reg_lambda': 0.21875127105792502}
# Best MSE on validation data: -14.61
# Training duration of best run: 33.18 s
# XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.8161667576652838, colsample_bynode=None,
#              colsample_bytree=0.9952508738467774, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.017166482580903034,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=346,
#              min_child_weight=128.0, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=261, n_jobs=-1,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = automl.predict(X_test)
print('mse', '=', sklearn_metric_loss_score('mse', y_pred, y_test))
# Out:
# mse = 18.359306867435738

# %%
time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history =get_output_from_log(filename='train_delays_experiment.log', time_budget=60)
plt.title('Learning Curve')
plt.xlabel('Wall Clock Time (s)')
plt.ylabel('Validation MSE')
plt.step(time_history, 1 - np.array(best_valid_loss_history), where='post')
plt.show()
