# %%
import pandas as pd
from cleaner import *

# %%
df = pd.read_csv('/home/lewis/code/TrainDelays/TrainDelays/data/EK_all_1205.csv')
# Out:
# /tmp/ipykernel_625017/1888686170.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/lewis/code/TrainDelays/TrainDelays/data/EK_all_1205.csv')

# %%
clean_df = cleaner(df)

# %%
clean_df
# Out:
#         TRAIN_SERVICE_CODE_AFFECTED SERVICE_GROUP_CODE_AFFECTED  \
# 3                          22215003                        EK03
# 4                          22215003                        EK03
# 5                          22218000                        EK99
# 6                          22218000                        EK99
# 7                          22218000                        EK99
# ...                             ...                         ...
# 546704                     22214000                        EK01
# 546705                     22204000                        EK01
# 546706                     22214000                        EK01
# 546707                     22214000                        EK01
# 546708                     22204000                        EK01
#
#        ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  UNIT_CLASS_AFFECTED  \
# 3                    BH                      Y                375.0
# ...

# %%
clean_df.to_csv('clean_data_final.csv', index=False)
