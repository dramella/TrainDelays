# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split, cross_validate

from data import *
from params import *

# %%
query = '''
SELECT * FROM `train-delays-406412.train_delays.train_delays_cleaned`
'''

# %%
df = get_data_from_bq(gcp_project=GCP_PROJECT, query=query)

# %%
df.head()
# Out:
#   TRUST_TRAIN_ID_AFFECTED PLANNED_ORIG_WTT_DATETIME_AFF  \
# 0              522N48MJ08           2018-12-08 11:45:00
# 1              522Y72MF19           2022-12-19 09:36:00
# 2              522N20MZ30           2023-01-30 20:17:00
# 3              522N02MX24           2018-11-24 18:33:00
# 4              522Y08MX24           2018-11-24 18:53:00
#
#   PLANNED_DEST_WTT_DATETIME_AFF  TRAIN_SERVICE_CODE_AFFECTED  \
# 0           2018-12-08 12:47:00                     22214000
# 1           2022-12-19 10:39:00                     22214000
# 2           2023-01-30 21:19:00                     22214000
# 3           2018-11-24 19:32:00                     22214000
# 4           2018-11-24 19:55:00                     22214000
#
#   SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  \
# 0                        EK01               SA                      Y
# 1                        EK01               WD                      Y
# 2                        EK01               WD                      Y
# 3                        EK01               SA                      Y
# 4                        EK01               SA                      Y
#
#   TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED RESPONSIBLE_MANAGER  \
# 0                    EMU                375.0                MEKJ
# 1                    EMU                378.0                MEKJ
# 2                    EMU                378.0                XQHM
# 3                    EMU                375.0                TEKA
# 4                    EMU                375.0                TEKA
#
#   INCIDENT_REASON REACTIONARY_REASON_CODE PERFORMANCE_EVENT_CODE  \
# 0              MD                      YI                      M
# 1              MD                      YI                      M
# 2              X8                      YI                      M
# 3              TG                      YI                      M
# 4              TG                      YI                      M
#
#    PFPI_MINUTES    Lat_OR   Lon_OR    STATION_OR   Lat_DES  Lon_DES  \
# 0           9.0  51.54343 -0.02447  HACKNEY WICK  51.54343 -0.02447
# 1          12.0  51.54343 -0.02447  HACKNEY WICK  51.54343 -0.02447
# 2           8.0  51.54343 -0.02447  HACKNEY WICK  51.54343 -0.02447
# 3          10.0  51.54343 -0.02447  HACKNEY WICK  51.54343 -0.02447
# 4          11.0  51.54343 -0.02447  HACKNEY WICK  51.54343 -0.02447
#
#     STATION_DES
# 0  HACKNEY WICK
# 1  HACKNEY WICK
# 2  HACKNEY WICK
# 3  HACKNEY WICK
# 4  HACKNEY WICK

# %%
df.loc[:, 'PLANNED_ORIG_WTT_DATETIME_AFF'] = pd.to_datetime(df.PLANNED_ORIG_WTT_DATETIME_AFF)
df.loc[:, 'ORIG_MONTH'] = df.PLANNED_ORIG_WTT_DATETIME_AFF.dt.month
df.loc[:, 'ORIG_DAY'] = df.PLANNED_ORIG_WTT_DATETIME_AFF.dt.day
df.loc[:, 'ORIG_HOUR'] = df.PLANNED_ORIG_WTT_DATETIME_AFF.dt.hour
df.loc[:, 'ORIG_MINUTE'] = df.PLANNED_ORIG_WTT_DATETIME_AFF.dt.minute
df.drop(columns='PLANNED_ORIG_WTT_DATETIME_AFF', inplace = True)

# %%
df.head()
# Out:
#   TRUST_TRAIN_ID_AFFECTED PLANNED_DEST_WTT_DATETIME_AFF  \
# 0              522N48MJ08           2018-12-08 12:47:00
# 1              522Y72MF19           2022-12-19 10:39:00
# 2              522N20MZ30           2023-01-30 21:19:00
# 3              522N02MX24           2018-11-24 19:32:00
# 4              522Y08MX24           2018-11-24 19:55:00
#
#    TRAIN_SERVICE_CODE_AFFECTED SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE  \
# 0                     22214000                        EK01               SA
# 1                     22214000                        EK01               WD
# 2                     22214000                        EK01               WD
# 3                     22214000                        EK01               SA
# 4                     22214000                        EK01               SA
#
#   APP_TIMETABLE_FLAG_AFF TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED  \
# 0                      Y                    EMU                375.0
# 1                      Y                    EMU                378.0
# 2                      Y                    EMU                378.0
# 3                      Y                    EMU                375.0
# 4                      Y                    EMU                375.0
#
#   RESPONSIBLE_MANAGER INCIDENT_REASON  ...    Lat_OR   Lon_OR    STATION_OR  \
# 0                MEKJ              MD  ...  51.54343 -0.02447  HACKNEY WICK
# 1                MEKJ              MD  ...  51.54343 -0.02447  HACKNEY WICK
# 2                XQHM              X8  ...  51.54343 -0.02447  HACKNEY WICK
# 3                TEKA              TG  ...  51.54343 -0.02447  HACKNEY WICK
# 4                TEKA              TG  ...  51.54343 -0.02447  HACKNEY WICK
#
#     Lat_DES  Lon_DES   STATION_DES  ORIG_MONTH  ORIG_DAY ORIG_HOUR  \
# 0  51.54343 -0.02447  HACKNEY WICK          12         8        11
# 1  51.54343 -0.02447  HACKNEY WICK          12        19         9
# 2  51.54343 -0.02447  HACKNEY WICK           1        30        20
# 3  51.54343 -0.02447  HACKNEY WICK          11        24        18
# 4  51.54343 -0.02447  HACKNEY WICK          11        24        18
#
#    ORIG_MINUTE
# 0           45
# 1           36
# 2           17
# 3           33
# 4           53
#
# [5 rows x 23 columns]

# %%
df.loc[:, 'PLANNED_DEST_WTT_DATETIME_AFF'] = pd.to_datetime(df.PLANNED_DEST_WTT_DATETIME_AFF)
df.loc[:, 'DEST_MONTH'] = df.PLANNED_DEST_WTT_DATETIME_AFF.dt.month
df.loc[:, 'DEST_DAY'] = df.PLANNED_DEST_WTT_DATETIME_AFF.dt.day
df.loc[:, 'DEST_HOUR'] = df.PLANNED_DEST_WTT_DATETIME_AFF.dt.hour
df.loc[:, 'DEST_MINUTE'] = df.PLANNED_DEST_WTT_DATETIME_AFF.dt.minute
df.drop(columns='PLANNED_DEST_WTT_DATETIME_AFF', inplace = True)

# %%
df.head()
# Out:
#   TRUST_TRAIN_ID_AFFECTED  TRAIN_SERVICE_CODE_AFFECTED  \
# 0              522N48MJ08                     22214000
# 1              522Y72MF19                     22214000
# 2              522N20MZ30                     22214000
# 3              522N02MX24                     22214000
# 4              522Y08MX24                     22214000
#
#   SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  \
# 0                        EK01               SA                      Y
# 1                        EK01               WD                      Y
# 2                        EK01               WD                      Y
# 3                        EK01               SA                      Y
# 4                        EK01               SA                      Y
#
#   TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED RESPONSIBLE_MANAGER  \
# 0                    EMU                375.0                MEKJ
# 1                    EMU                378.0                MEKJ
# 2                    EMU                378.0                XQHM
# 3                    EMU                375.0                TEKA
# 4                    EMU                375.0                TEKA
#
#   INCIDENT_REASON REACTIONARY_REASON_CODE  ...  Lon_DES   STATION_DES  \
# 0              MD                      YI  ... -0.02447  HACKNEY WICK
# 1              MD                      YI  ... -0.02447  HACKNEY WICK
# 2              X8                      YI  ... -0.02447  HACKNEY WICK
# 3              TG                      YI  ... -0.02447  HACKNEY WICK
# 4              TG                      YI  ... -0.02447  HACKNEY WICK
#
#    ORIG_MONTH  ORIG_DAY ORIG_HOUR  ORIG_MINUTE  DEST_MONTH DEST_DAY  \
# 0          12         8        11           45          12        8
# 1          12        19         9           36          12       19
# 2           1        30        20           17           1       30
# 3          11        24        18           33          11       24
# 4          11        24        18           53          11       24
#
#    DEST_HOUR  DEST_MINUTE
# 0         12           47
# 1         10           39
# 2         21           19
# 3         19           32
# 4         19           55
#
# [5 rows x 26 columns]

# %%
df.head()
# Out:
#   TRUST_TRAIN_ID_AFFECTED  TRAIN_SERVICE_CODE_AFFECTED  \
# 0              522N48MJ08                     22214000
# 1              522Y72MF19                     22214000
# 2              522N20MZ30                     22214000
# 3              522N02MX24                     22214000
# 4              522Y08MX24                     22214000
#
#   SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  \
# 0                        EK01               SA                      Y
# 1                        EK01               WD                      Y
# 2                        EK01               WD                      Y
# 3                        EK01               SA                      Y
# 4                        EK01               SA                      Y
#
#   TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED RESPONSIBLE_MANAGER  \
# 0                    EMU                375.0                MEKJ
# 1                    EMU                378.0                MEKJ
# 2                    EMU                378.0                XQHM
# 3                    EMU                375.0                TEKA
# 4                    EMU                375.0                TEKA
#
#   INCIDENT_REASON REACTIONARY_REASON_CODE  ...  Lon_DES   STATION_DES  \
# 0              MD                      YI  ... -0.02447  HACKNEY WICK
# 1              MD                      YI  ... -0.02447  HACKNEY WICK
# 2              X8                      YI  ... -0.02447  HACKNEY WICK
# 3              TG                      YI  ... -0.02447  HACKNEY WICK
# 4              TG                      YI  ... -0.02447  HACKNEY WICK
#
#    ORIG_MONTH  ORIG_DAY ORIG_HOUR  ORIG_MINUTE  DEST_MONTH DEST_DAY  \
# 0          12         8        11           45          12        8
# 1          12        19         9           36          12       19
# 2           1        30        20           17           1       30
# 3          11        24        18           33          11       24
# 4          11        24        18           53          11       24
#
#    DEST_HOUR  DEST_MINUTE
# 0         12           47
# 1         10           39
# 2         21           19
# 3         19           32
# 4         19           55
#
# [5 rows x 26 columns]

# %%
df['TRAIN_SERVICE_CODE_AFFECTED'].unique()
# Out:
# array([22214000, 22204000, 21921000, 22216000, 25234001, 21234001,
#        21252001, 21235001, 25235001, 22206000, 22215003, 22218000,
#        21237001, 22215002])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor

# %%
X = df.drop(columns=['PFPI_MINUTES'])
y = df['PFPI_MINUTES']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

# %%
X_train.head()
# Out:
#        TRUST_TRAIN_ID_AFFECTED  TRAIN_SERVICE_CODE_AFFECTED  \
# 165480              529E11MC09                     22218000
# 48643               879D46MT15                     22215003
# 439286              872N97MS17                     22214000
# 158268              879B12MC22                     22218000
# 235038              722J25M707                     21921000
#
#        SERVICE_GROUP_CODE_AFFECTED ENGLISH_DAY_TYPE APP_TIMETABLE_FLAG_AFF  \
# 165480                        EK99               WD                      Y
# 48643                         EK03               WD                      Y
# 439286                        EK01               WD                      Y
# 158268                        EK99               WD                      Y
# 235038                        EK01               WD                      Y
#
#        TRACTION_TYPE_AFFECTED  UNIT_CLASS_AFFECTED RESPONSIBLE_MANAGER  \
# 165480                    EMU                375.0                ZQBG
# 48643                     EMU                378.0                IQM1
# 439286                    EMU                375.0                QQHP
# 158268                    EMU                375.0                SETG
# 235038                    EMU                710.0                IQH2
#
#        INCIDENT_REASON REACTIONARY_REASON_CODE  ...  Lon_DES  \
# 165480              ZS                      YD  ... -0.05975
# 48643               IR                    None  ... -0.04083
# 439286              QN                      YB  ... -0.24454
# 158268              RB                      YD  ... -0.05975
# 235038              JS                    None  ...  0.04445
#
#                          STATION_DES  ORIG_MONTH ORIG_DAY  ORIG_HOUR  \
# 165480                          None           4        9          8
# 48643                 NEW CROSS GATE           6       15         16
# 439286                          None          10       17         16
# 158268                          None           3       22          8
# 235038  Woodgrange Park Rail Station           7       10         21
#
#         ORIG_MINUTE DEST_MONTH  DEST_DAY  DEST_HOUR  DEST_MINUTE
# 165480           29          4         9          8           50
# 48643            46          6        15         17           36
# 439286            9         10        17         17           11
# 158268           17          3        22          8           59
# 235038           51          7        10         22           26
#
# [5 rows x 25 columns]

# %%
model = SGDRegressor(max_iter=1000, loss='mean_absolute_error')

# %%
X_train_processed = preprocess(X_train)
